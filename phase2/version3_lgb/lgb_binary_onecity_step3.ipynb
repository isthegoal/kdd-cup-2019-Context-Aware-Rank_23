# %% [markdown]
# # 另一种二分类方式，把之前的one to mul转成 mul to mul的形式

# %%
import os
import gc
import ast
import math
import time
import json 
import numpy as np
import pandas as pd
import lightgbm as lgb
import seaborn as sns
from itertools import product
from datetime import datetime
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

from tqdm import tqdm
from sklearn.cluster import KMeans
from sklearn.metrics import f1_score, accuracy_score,recall_score,precision_score
from sklearn.model_selection import StratifiedKFold
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
from sklearn.preprocessing import MinMaxScaler,StandardScaler,LabelEncoder

# %%
city = 'shenzhen'
if city == 'beijing':
    data_path = '../data/base_feat/base_feat_beijing_06-09_16_15.csv'
elif city == 'shanghai':
    data_path = '../data/base_feat/base_feat_shanghai_06-09_23_23.parquet'
elif city =='shenzhen':
    data_path = 'E:/Machine-learning/kdd_cup_2019/phase2/version3_lgb/shenzhen_version3_2019-06-11_16_20_all_features.csv'
data = pd.read_csv(data_path)

# %%
data=data.iloc[:4000]

# %%
# ==========================对plans进行拆分展开成二分类==================================
print('3 拆分plans构建二分类数据============================================')
data['plans_json'] = data['plans'].fillna('[]').apply(lambda x: json.loads(x))
data = data.drop('plans', axis=1)

plans = np.dstack((np.repeat(data['sid'].values,list(map(len,data['plans_json'].values))),np.concatenate(data['plans_json'].values)))
plans = pd.DataFrame(plans[0],columns=['sid','plans'])
plans = pd.concat([plans, pd.DataFrame.from_dict(plans['plans'].tolist())], axis=1)

plans.drop_duplicates(subset = ['sid','transport_mode'], inplace=True)
# plans['price'] = plans[['price','transport_mode']].apply(fillna_price, axis=1)

print('3.1 构建二分类plans的特征=============================================')
plans['price'] = plans['price'].apply(lambda x:0 if x == '' else int(x))
plans['price_yuan'] = plans['price']//100
plans['distance_eta'] = plans['distance']/plans['eta']

plans['distance_price'] = plans['distance']*plans['price'] 
plans['eta_price'] = plans['eta'] * plans['price']

plans['self_rank'] = plans.groupby(['sid']).cumcount()
plans['price_rank'] = plans.groupby(['sid'])['price'].rank()
plans['eta_rank'] = plans.groupby(['sid'])['eta'].rank()
plans['distance_rank'] = plans.groupby(['sid'])['distance'].rank()
plans['distance_eta_rank'] = plans.groupby(['sid'])['distance_eta'].rank()
plans['distance_price_price'] = plans.groupby(['sid'])['distance_price'].rank()
plans['eta_price_rank'] = plans.groupby(['sid'])['eta_price'].rank()

gc.collect()
# Out:
# 3 拆分plans构建二分类数据============================================
# 3.1 构建二分类plans的特征=============================================
# 56

# %%
plans
# Out:
#            sid                                              plans  distance  \
# 0      1972109  {'distance': 6238, 'price': 300, 'eta': 1713, ...      6238
# 1      1972109  {'distance': 5864, 'price': '', 'eta': 862, 't...      5864
# 2      1972109  {'distance': 5864, 'price': 2200, 'eta': 1102,...      5864
# 3      1972109  {'distance': 4323, 'price': '', 'eta': 1304, '...      4323
# 4      1972109  {'distance': 5711, 'price': 200, 'eta': 1883, ...      5711
# 5      1972109  {'distance': 6237, 'price': 300, 'eta': 1914, ...      6237
# 6      1972109  {'distance': 4186, 'price': '', 'eta': 3725, '...      4186
# 7      1684471  {'distance': 527, 'price': '', 'eta': 450, 'tr...       527
# 8      1684471  {'distance': 872, 'price': '', 'eta': 261, 'tr...       872
# 9      1684471  {'distance': 1214, 'price': '', 'eta': 310, 't...      1214
# 10     1949310  {'distance': 45014, 'price': '', 'eta': 8333, ...     45014
# 11     1949310  {'distance': 41648, 'price': '', 'eta': 3418, ...     41648
# 12     1949310  {'distance': 41648, 'price': 17300, 'eta': 359...     41648
# 13     1949310  {'distance': 53243, 'price': 6200, 'eta': 6143...     53243
# 14     1949310  {'distance': 44301, 'price': '', 'eta': 9132, ...     44301
# 15     1679483  {'distance': 31325, 'price': '', 'eta': 5463, ...     31325
# 16     1679483  {'distance': 28654, 'price': '', 'eta': 2690, ...     28654
# 17     1679483  {'distance': 28654, 'price': 9400, 'eta': 2930...     28654
# 18     1679483  {'distance': 31131, 'price': 2300, 'eta': 4315...     31131
# 19     1679483  {'distance': 32777, 'price': '', 'eta': 6837, ...     32777
# 20     1892098  {'distance': 6474, 'price': 200, 'eta': 1879, ...      6474
# 21     1892098  {'distance': 5371, 'price': '', 'eta': 593, 't...      5371
# 22     1892098  {'distance': 5371, 'price': 1900, 'eta': 713, ...      5371
# 23     1892098  {'distance': 5534, 'price': '', 'eta': 1671, '...      5534
# 25     1776172  {'distance': 14371, 'price': 500, 'eta': 2432,...     14371
# 26     1776172  {'distance': 17175, 'price': 1800, 'eta': 2393...     17175
# 27     1776172  {'distance': 14828, 'price': '', 'eta': 2702, ...     14828
# 28     1776172  {'distance': 14828, 'price': 6000, 'eta': 2942...     14828
# 29     1776172  {'distance': 14703, 'price': 700, 'eta': 3507,...     14703
# 30     1776172  {'distance': 14462, 'price': '', 'eta': 4658, ...     14462
# ...        ...                                                ...       ...
# 17551  1990016  {'distance': 10930, 'price': 3700, 'eta': 1752...     10930
# 17552  1990016  {'distance': 10888, 'price': 400, 'eta': 2025,...     10888
# 17553  1990016  {'distance': 12133, 'price': 250, 'eta': 3607,...     12133
# 17554  1567347  {'distance': 57702, 'price': 3200, 'eta': 6719...     57702
# 17555  1567347  {'distance': 53865, 'price': '', 'eta': 3421, ...     53865
# 17556  1567347  {'distance': 53865, 'price': 19200, 'eta': 372...     53865
# 17557  1567347  {'distance': 69831, 'price': 2400, 'eta': 6732...     69831
# 17559  1669784  {'distance': 477, 'price': '', 'eta': 407, 'tr...       477
# 17560  1669784  {'distance': 503, 'price': '', 'eta': 111, 'tr...       503
# 17561  1669784  {'distance': 503, 'price': '', 'eta': 150, 'tr...       503
# 17562  1513144  {'distance': 1767, 'price': 1300, 'eta': 706, ...      1767
# 17563  1513144  {'distance': 1767, 'price': '', 'eta': 526, 't...      1767
# 17564  1513144  {'distance': 1756, 'price': '', 'eta': 526, 't...      1756
# 17565  1513144  {'distance': 1700, 'price': '', 'eta': 1472, '...      1700
# 17566  1513144  {'distance': 1700, 'price': 200, 'eta': 1484, ...      1700
# 17568  1723046  {'distance': 20331, 'price': 700, 'eta': 3709,...     20331
# 17569  1723046  {'distance': 12973, 'price': '', 'eta': 1945, ...     12973
# 17570  1723046  {'distance': 12973, 'price': 4700, 'eta': 2065...     12973
# 17571  1723046  {'distance': 20647, 'price': 600, 'eta': 3108,...     20647
# 17572  1723046  {'distance': 16331, 'price': 250, 'eta': 4754,...     16331
# 17573  1763998  {'distance': 11117, 'price': 400, 'eta': 2018,...     11117
# 17574  1763998  {'distance': 9266, 'price': '', 'eta': 1086, '...      9266
# 17575  1763998  {'distance': 9266, 'price': 4100, 'eta': 1266,...      9266
# 17576  1763998  {'distance': 11041, 'price': 400, 'eta': 2161,...     11041
# 17577  1763998  {'distance': 8657, 'price': '', 'eta': 2613, '...      8657
# 17578  1763998  {'distance': 12998, 'price': 650, 'eta': 2838,...     12998
# 17579  1847790  {'distance': 19981, 'price': 600, 'eta': 3007,...     19981
# 17580  1847790  {'distance': 25000, 'price': '', 'eta': 2620, ...     25000
# 17581  1847790  {'distance': 19873, 'price': 1900, 'eta': 2949...     19873
# 17582  1847790  {'distance': 19985, 'price': 800, 'eta': 3358,...     19985
#
#         eta  price  transport_mode  price_yuan  distance_eta  distance_price  \
# 0      1713    300               9           3      3.641565         1871400
# 1       862      0               3           0      6.802784               0
# 2      1102   2200               4          22      5.321234        12900800
# 3      1304      0               6           0      3.315184               0
# 4      1883    200               1           2      3.032926         1142200
# 5      1914    300               2           3      3.258621         1871100
# 6      3725      0               5           0      1.123758               0
# 7       450      0               5           0      1.171111               0
# 8       261      0               6           0      3.340996               0
# 9       310      0               3           0      3.916129               0
# 10     8333      0               7           0      5.401896               0
# 11     3418      0               3           0     12.184903               0
# 12     3598  17300               4         173     11.575320       720510400
# 13     6143   6200              10          62      8.667264       330106600
# 14     9132      0               1           0      4.851183               0
# 15     5463      0               7           0      5.734029               0
# 16     2690      0               3           0     10.652045               0
# 17     2930   9400               4          94      9.779522       269347600
# 18     4315   2300              10          23      7.214600        71601300
# 19     6837      0               1           0      4.794062               0
# 20     1879    200               1           2      3.445450         1294800
# 21      593      0               3           0      9.057336               0
# 22      713   1900               4          19      7.532959        10204900
# 23     1671      0               6           0      3.311789               0
# 25     2432    500               9           5      5.909128         7185500
# 26     2393   1800              10          18      7.177183        30915000
# 27     2702      0               3           0      5.487787               0
# 28     2942   6000               4          60      5.040109        88968000
# 29     3507    700               7           7      4.192472        10292100
# 30     4658      0               1           0      3.104766               0
# ...     ...    ...             ...         ...           ...             ...
# 17551  1752   3700               4          37      6.238584        40441000
# 17552  2025    400               2           4      5.376790         4355200
# 17553  3607    250               1           2      3.363737         3033250
# 17554  6719   3200               1          32      8.587885       184646400
# 17555  3421      0               3           0     15.745396               0
# 17556  3721  19200               4         192     14.475947      1034208000
# 17557  6732   2400              10          24     10.372995       167594400
# 17559   407      0               5           0      1.171990               0
# 17560   111      0               3           0      4.531532               0
# 17561   150      0               6           0      3.353333               0
# 17562   706   1300               4          13      2.502833         2297100
# 17563   526      0               3           0      3.359316               0
# 17564   526      0               6           0      3.338403               0
# 17565  1472      0               5           0      1.154891               0
# 17566  1484    200               1           2      1.145553          340000
# 17568  3709    700               7           7      5.481531        14231700
# 17569  1945      0               3           0      6.669923               0
# 17570  2065   4700               4          47      6.282324        60973100
# 17571  3108    600               9           6      6.643179        12388200
# 17572  4754    250               1           2      3.435212         4082750
# 17573  2018    400               9           4      5.508920         4446800
# 17574  1086      0               3           0      8.532228               0
# 17575  1266   4100               4          41      7.319115        37990600
# 17576  2161    400               2           4      5.109209         4416400
# 17577  2613      0               6           0      3.313050               0
# 17578  2838    650               7           6      4.579986         8448700
# 17579  3007    600               2           6      6.644829        11988600
# 17580  2620      0               3           0      9.541985               0
# 17581  2949   1900              10          19      6.738895        37758700
# 17582  3358    800               7           8      5.951459        15988000
#
#        eta_price  self_rank  price_rank  eta_rank  distance_rank  \
# 0         513900          0         5.5       4.0            7.0
# 1              0          1         2.0       1.0            4.5
# 2        2424400          2         7.0       2.0            4.5
# 3              0          3         2.0       3.0            2.0
# 4         376600          4         4.0       5.0            3.0
# 5         574200          5         5.5       6.0            6.0
# 6              0          6         2.0       7.0            1.0
# 7              0          0         2.0       3.0            1.0
# 8              0          1         2.0       1.0            2.0
# 9              0          2         2.0       2.0            3.0
# 10             0          0         2.0       4.0            4.0
# 11             0          1         2.0       1.0            1.5
# 12      62245400          2         5.0       2.0            1.5
# 13      38086600          3         4.0       3.0            5.0
# 14             0          4         2.0       5.0            3.0
# 15             0          0         2.0       4.0            4.0
# 16             0          1         2.0       1.0            1.5
# 17      27542000          2         5.0       2.0            1.5
# 18       9924500          3         4.0       3.0            3.0
# 19             0          4         2.0       5.0            5.0
# 20        375800          0         3.0       4.0            4.0
# 21             0          1         1.5       1.0            1.5
# 22       1354700          2         4.0       2.0            1.5
# 23             0          3         1.5       3.0            3.0
# 25       1216000          0         3.0       2.0            1.0
# 26       4307400          1         5.0       1.0            6.0
# 27             0          2         1.5       3.0            4.5
# 28      17652000          3         6.0       4.0            4.5
# 29       2454900          4         4.0       5.0            3.0
# 30             0          5         1.5       6.0            2.0
# ...          ...        ...         ...       ...            ...
# 17551    6482400          1         4.0       1.0            2.0
# 17552     810000          2         2.5       3.0            1.0
# 17553     901750          3         1.0       4.0            4.0
# 17554   21500800          0         3.0       3.0            3.0
# 17555          0          1         1.0       1.0            1.5
# 17556   71443200          2         4.0       2.0            1.5
# 17557   16156800          3         2.0       4.0            4.0
# 17559          0          0         2.0       3.0            1.0
# 17560          0          1         2.0       1.0            2.5
# 17561          0          2         2.0       2.0            2.5
# 17562     917800          0         5.0       3.0            4.5
# 17563          0          1         2.0       1.5            4.5
# 17564          0          2         2.0       1.5            3.0
# 17565          0          3         2.0       4.0            1.5
# 17566     296800          4         4.0       5.0            1.5
# 17568    2596300          0         4.0       4.0            4.0
# 17569          0          1         1.0       1.0            1.5
# 17570    9705500          2         5.0       2.0            1.5
# 17571    1864800          3         3.0       3.0            5.0
# 17572    1188500          4         2.0       5.0            3.0
# 17573     807200          0         3.5       3.0            5.0
# 17574          0          1         1.5       1.0            2.5
# 17575    5190600          2         6.0       2.0            2.5
# 17576     864400          3         3.5       4.0            4.0
# 17577          0          4         1.5       5.0            1.0
# 17578    1844700          5         5.0       6.0            6.0
# 17579    1804200          0         2.0       3.0            2.0
# 17580          0          1         1.0       1.0            4.0
# 17581    5603100          2         4.0       2.0            1.0
# 17582    2686400          3         3.0       4.0            3.0
#
#        distance_eta_rank  distance_price_price  eta_price_rank
# 0                    5.0                   6.0             5.0
# 1                    7.0                   2.0             2.0
# 2                    6.0                   7.0             7.0
# 3                    4.0                   2.0             2.0
# 4                    2.0                   4.0             4.0
# 5                    3.0                   5.0             6.0
# 6                    1.0                   2.0             2.0
# 7                    1.0                   2.0             2.0
# 8                    2.0                   2.0             2.0
# 9                    3.0                   2.0             2.0
# 10                   2.0                   2.0             2.0
# 11                   5.0                   2.0             2.0
# 12                   4.0                   5.0             5.0
# 13                   3.0                   4.0             4.0
# 14                   1.0                   2.0             2.0
# 15                   2.0                   2.0             2.0
# 16                   5.0                   2.0             2.0
# 17                   4.0                   5.0             5.0
# 18                   3.0                   4.0             4.0
# 19                   1.0                   2.0             2.0
# 20                   2.0                   3.0             3.0
# 21                   4.0                   1.5             1.5
# 22                   3.0                   4.0             4.0
# 23                   1.0                   1.5             1.5
# 25                   5.0                   3.0             3.0
# 26                   6.0                   5.0             5.0
# 27                   4.0                   1.5             1.5
# 28                   3.0                   6.0             6.0
# 29                   2.0                   4.0             4.0
# 30                   1.0                   1.5             1.5
# ...                  ...                   ...             ...
# 17551                4.0                   4.0             4.0
# 17552                2.0                   2.0             2.0
# 17553                1.0                   1.0             3.0
# 17554                1.0                   3.0             3.0
# 17555                4.0                   1.0             1.0
# 17556                3.0                   4.0             4.0
# 17557                2.0                   2.0             2.0
# 17559                1.0                   2.0             2.0
# 17560                3.0                   2.0             2.0
# 17561                2.0                   2.0             2.0
# 17562                3.0                   5.0             5.0
# 17563                5.0                   2.0             2.0
# 17564                4.0                   2.0             2.0
# 17565                2.0                   2.0             2.0
# 17566                1.0                   4.0             4.0
# 17568                2.0                   4.0             4.0
# 17569                5.0                   1.0             1.0
# 17570                3.0                   5.0             5.0
# 17571                4.0                   3.0             3.0
# 17572                1.0                   2.0             2.0
# 17573                4.0                   4.0             3.0
# 17574                6.0                   1.5             1.5
# 17575                5.0                   6.0             6.0
# 17576                3.0                   3.0             4.0
# 17577                1.0                   1.5             1.5
# 17578                2.0                   5.0             5.0
# 17579                2.0                   2.0             2.0
# 17580                4.0                   1.0             1.0
# 17581                3.0                   4.0             4.0
# 17582                1.0                   3.0             3.0
#
# [16704 rows x 17 columns]

# %%
profiles = pd.read_csv('../data/data_set_phase2/profiles.csv') 
profiles
import gc 
gc.collect()
data  = data.merge(profiles, 'left', ['pid'])

# %%
data.columns.values
# Out:
# array(['click_mode', 'd', 'o', 'pid', 'plan_time', 'req_time', 'sid',
#        'o_lng', 'o_lat', 'd_lng', 'd_lat', 'city_flag_o',
#        'od_manhattan_distance', 'od_manhattan_distance_detail',
#        'o_main_centroid_mean_dis', 'd_main_centroid_mean_dis',
#        'o_main_centroid_mode_dis', 'd_main_centroid_mode_dis',
#        "('o_cluster', 'd_cluster')", 'o_cluster', 'd_cluster',
#        'manhattan', 'euclidean', 'delta_longitude', 'delta_latitude',
#        'pickup_x', 'pickup_y', 'pickup_z', 'dropoff_x', 'dropoff_y',
#        'dropoff_z', 'direction', 'req_time_hour', 'req_time_weekday',
#        'req_time_minute', 'req_time_date_d', 'time_diff', 'diff_6_cloc',
#        'diff_12_clock', 'diff_18_clock', 'diff_24_clock', 'svd_fea_0',
#        'svd_fea_1', 'svd_fea_2', 'svd_fea_3', 'svd_fea_4', 'svd_fea_5',
#        'svd_fea_6', 'svd_fea_7', 'svd_fea_8', 'svd_fea_9', 'plans_json',
#        'mode_feas_0', 'mode_feas_1', 'mode_feas_2', 'mode_feas_3',
#        'mode_feas_4', 'mode_feas_5', 'mode_feas_6', 'mode_feas_7',
#        'mode_feas_8', 'mode_feas_9', 'mode_feas_10', 'mode_feas_11',
#        'max_dist', 'min_dist', 'mean_dist', 'std_dist', 'max_price',
#        'min_price', 'mean_price', 'std_price', 'max_eta', 'min_eta',
#        'mean_eta', 'std_eta', 'max_dist_mode', 'min_dist_mode',
#        'max_price_mode', 'min_price_mode', 'max_eta_mode', 'min_eta_mode',
#        'first_mode', 'svd_mode_0', 'svd_mode_1', 'svd_mode_2',
#        'svd_mode_3', 'svd_mode_4', 'svd_mode_5', 'svd_mode_6',
#        'svd_mode_7', 'svd_mode_8', 'svd_mode_9', 'plan_model_1_dist',
#        'plan_model_1_price', 'plan_model_1_eta', 'plan_model_1_rank',
#        'plan_model_2_dist', 'plan_model_2_price', 'plan_model_2_eta',
#        'plan_model_2_rank', 'plan_model_3_dist', 'plan_model_3_price',
#        'plan_model_3_eta', 'plan_model_3_rank', 'plan_model_4_dist',
#        'plan_model_4_price', 'plan_model_4_eta', 'plan_model_4_rank',
#        'plan_model_5_dist', 'plan_model_5_price', 'plan_model_5_eta',
#        'plan_model_5_rank', 'plan_model_6_dist', 'plan_model_6_price',
#        'plan_model_6_eta', 'plan_model_6_rank', 'plan_model_7_dist',
#        'plan_model_7_price', 'plan_model_7_eta', 'plan_model_7_rank',
#        'plan_model_8_dist', 'plan_model_8_price', 'plan_model_8_eta',
#        'plan_model_8_rank', 'plan_model_9_dist', 'plan_model_9_price',
#        'plan_model_9_eta', 'plan_model_9_rank', 'plan_model_10_dist',
#        'plan_model_10_price', 'plan_model_10_eta', 'plan_model_10_rank',
#        'plan_model_11_dist', 'plan_model_11_price', 'plan_model_11_eta',
#        'plan_model_11_rank', 'o_appear_count', 'd_appear_count',
#        'o_appear_count_rank', 'd_appear_count_rank',
#        'o_appear_count_rank_buguiyi', 'd_appear_count_rank_buguiyi',
#        'od_couple', 'od_couple_count', 'od_couple_rank',
#        'od_couple_rank_buguiyi', 'plan_model_1_dist_rank',
#        'plan_model_1_eta_rank', 'plan_model_1_price_rank',
#        'plan_model_1_rank_rank', 'plan_model_1_dist_rank_guiyi',
#        'plan_model_1_eta_rank_guiyi', 'plan_model_1_price_rank_guiyi',
#        'plan_model_1_rank_rank_guiyi', 'plan_model_2_dist_rank',
#        'plan_model_2_eta_rank', 'plan_model_2_price_rank',
#        'plan_model_2_rank_rank', 'plan_model_2_dist_rank_guiyi',
#        'plan_model_2_eta_rank_guiyi', 'plan_model_2_price_rank_guiyi',
#        'plan_model_2_rank_rank_guiyi', 'plan_model_3_dist_rank',
#        'plan_model_3_eta_rank', 'plan_model_3_price_rank',
#        'plan_model_3_rank_rank', 'plan_model_3_dist_rank_guiyi',
#        'plan_model_3_eta_rank_guiyi', 'plan_model_3_price_rank_guiyi',
#        'plan_model_3_rank_rank_guiyi', 'plan_model_4_dist_rank',
#        'plan_model_4_eta_rank', 'plan_model_4_price_rank',
#        'plan_model_4_rank_rank', 'plan_model_4_dist_rank_guiyi',
#        'plan_model_4_eta_rank_guiyi', 'plan_model_4_price_rank_guiyi',
#        'plan_model_4_rank_rank_guiyi', 'plan_model_5_dist_rank',
#        'plan_model_5_eta_rank', 'plan_model_5_price_rank',
#        'plan_model_5_rank_rank', 'plan_model_5_dist_rank_guiyi',
#        'plan_model_5_eta_rank_guiyi', 'plan_model_5_price_rank_guiyi',
#        'plan_model_5_rank_rank_guiyi', 'plan_model_6_dist_rank',
#        'plan_model_6_eta_rank', 'plan_model_6_price_rank',
#        'plan_model_6_rank_rank', 'plan_model_6_dist_rank_guiyi',
#        'plan_model_6_eta_rank_guiyi', 'plan_model_6_price_rank_guiyi',
#        'plan_model_6_rank_rank_guiyi', 'plan_model_7_dist_rank',
#        'plan_model_7_eta_rank', 'plan_model_7_price_rank',
#        'plan_model_7_rank_rank', 'plan_model_7_dist_rank_guiyi',
#        'plan_model_7_eta_rank_guiyi', 'plan_model_7_price_rank_guiyi',
#        'plan_model_7_rank_rank_guiyi', 'plan_model_8_dist_rank',
#        'plan_model_8_eta_rank', 'plan_model_8_price_rank',
#        'plan_model_8_rank_rank', 'plan_model_8_dist_rank_guiyi',
#        'plan_model_8_eta_rank_guiyi', 'plan_model_8_price_rank_guiyi',
#        'plan_model_8_rank_rank_guiyi', 'plan_model_9_dist_rank',
#        'plan_model_9_eta_rank', 'plan_model_9_price_rank',
#        'plan_model_9_rank_rank', 'plan_model_9_dist_rank_guiyi',
#        'plan_model_9_eta_rank_guiyi', 'plan_model_9_price_rank_guiyi',
#        'plan_model_9_rank_rank_guiyi', 'plan_model_10_dist_rank',
#        'plan_model_10_eta_rank', 'plan_model_10_price_rank',
#        'plan_model_10_rank_rank', 'plan_model_10_dist_rank_guiyi',
#        'plan_model_10_eta_rank_guiyi', 'plan_model_10_price_rank_guiyi',
#        'plan_model_10_rank_rank_guiyi', 'plan_model_11_dist_rank',
#        'plan_model_11_eta_rank', 'plan_model_11_price_rank',
#        'plan_model_11_rank_rank', 'plan_model_11_dist_rank_guiyi',
#        'plan_model_11_eta_rank_guiyi', 'plan_model_11_price_rank_guiyi',
#        'plan_model_11_rank_rank_guiyi', 'pid_mode_0_x', 'pid_mode_1_x',
#        'pid_mode_2_x', 'pid_mode_3_x', 'pid_mode_4_x', 'pid_mode_5_x',
#        'pid_mode_6_x', 'pid_mode_7_x', 'pid_mode_8_x', 'pid_mode_9_x',
#        'pid_mode_10_x', 'pid_mode_11_x', 'pid_mode_0_y', 'pid_mode_1_y',
#        'pid_mode_2_y', 'pid_mode_3_y', 'pid_mode_4_y', 'pid_mode_5_y',
#        'pid_mode_6_y', 'pid_mode_7_y', 'pid_mode_8_y', 'pid_mode_9_y',
#        'pid_mode_10_y', 'pid_mode_11_y', 'pid_mode_0', 'pid_mode_1',
#        'pid_mode_2', 'pid_mode_3', 'pid_mode_4', 'pid_mode_5',
#        'pid_mode_6', 'pid_mode_7', 'pid_mode_8', 'pid_mode_9',
#        'pid_mode_10', 'pid_mode_11', 'sloc_count', 'eloc_as_sloc_count',
#        'sloc_as_eloc_count', 'eloc_count', 'user_eloc_as_sloc_count',
#        'user_sloc_as_eloc_count', 'user_sloc_count',
#        'sloc_eloc_common_eloc_count', 'sloc_eloc_common_sloc_count',
#        'sloc_eloc_common_conn1_count', 'sloc_eloc_common_conn2_count',
#        'sloc_eloc_common_eloc_rate', 'sloc_eloc_common_sloc_rate',
#        'sloc_eloc_common_conn1_rate', 'sloc_eloc_common_conn2_rate',
#        'user_sloc_eloc_common_eloc_count',
#        'user_sloc_eloc_common_sloc_count',
#        'user_sloc_eloc_common_conn1_count',
#        'user_sloc_eloc_common_conn2_count',
#        'user_sloc_eloc_common_eloc_rate',
#        'user_sloc_eloc_common_sloc_rate',
#        'user_sloc_eloc_common_conn1_rate',
#        'user_sloc_eloc_common_conn2_rate', 'p0', 'p1', 'p2', 'p3', 'p4',
#        'p5', 'p6', 'p7', 'p8', 'p9', 'p10', 'p11', 'p12', 'p13', 'p14',
#        'p15', 'p16', 'p17', 'p18', 'p19', 'p20', 'p21', 'p22', 'p23',
#        'p24', 'p25', 'p26', 'p27', 'p28', 'p29', 'p30', 'p31', 'p32',
#        'p33', 'p34', 'p35', 'p36', 'p37', 'p38', 'p39', 'p40', 'p41',
#        'p42', 'p43', 'p44', 'p45', 'p46', 'p47', 'p48', 'p49', 'p50',
#        'p51', 'p52', 'p53', 'p54', 'p55', 'p56', 'p57', 'p58', 'p59',
#        'p60', 'p61', 'p62', 'p63', 'p64', 'p65'], dtype=object)

# %%
print('特征加载')
######################################   非特征    ######################################
or_feature  = ['req_time','click_mode','sid']

######################################   原始特征    ######################################
cate_feature = ['pid'] 
profile_feature = ['p' + str(i) for i in range(66)]

origin_num_feature = ['o_lng', 'o_lat', 'd_lng', 'd_lat'] + profile_feature + cate_feature
      
########################################  经纬度特征  ##########################################
od_feature = ['od_manhattan_distance', 'od_manhattan_distance_detail', 'o_main_centroid_mean_dis',
              'd_main_centroid_mean_dis', 'o_main_centroid_mode_dis', 'd_main_centroid_mode_dis', 
              'o_cluster', 'd_cluster']

########################################  距离特征  ##########################################
distance_feature = ['manhattan','euclidean', 'od_manhattan_distance_detail', 'delta_longitude','delta_latitude','pickup_x','pickup_y','pickup_z','dropoff_x','dropoff_y','dropoff_z','direction']

################################  plan_time & req_time特征  ###################################
#所有时间特征
all_time_feature = ['req_time_hour', 'req_time_weekday', 'req_time_minute', 'req_time_date_d', 'time_diff', 
                'diff_6_cloc', 'diff_12_clock', 'diff_18_clock', 'diff_24_clock']
#选择的时间特征
time_feature=['req_time_hour', 'time_diff', 'diff_6_cloc', 'diff_12_clock', 'diff_18_clock', 'diff_24_clock']

################################  对profile的降维提取特征  ###################################
#所有特征
all_profiles_svd_feature = ['svd_fea_{}'.format(i) for i in range(10)]

##############################  plans百度地图推荐交通方式特征  #################################
plan_feature = ['mode_feas_0', 'mode_feas_1', 'mode_feas_2', 'mode_feas_3', 'mode_feas_4', 'mode_feas_5', 
                'mode_feas_6', 'mode_feas_7', 'mode_feas_8', 'mode_feas_9', 'mode_feas_10', 'mode_feas_11', 
               'max_dist', 'min_dist', 'mean_dist', 'std_dist', 'max_price', 'min_price', 'mean_price', 
                'std_price', 'max_eta', 'min_eta', 'mean_eta', 'std_eta', 'max_dist_mode', 'min_dist_mode',
                'max_price_mode', 'min_price_mode', 'max_eta_mode', 'min_eta_mode', 'first_mode',
                'svd_mode_0', 'svd_mode_1', 'svd_mode_2', 'svd_mode_3', 'svd_mode_4', 'svd_mode_5', 
                'svd_mode_6', 'svd_mode_7', 'svd_mode_8', 'svd_mode_9']

##############################  位置点和od对出现次数及排序特征  #################################
#所有特征
all_od_appear_feature = ['o_appear_count','d_appear_count','o_appear_count_rank','d_appear_count_rank',
                         'o_appear_count_rank_buguiyi','d_appear_count_rank_buguiyi',
                         'od_couple','od_couple_count','od_couple_rank','od_couple_rank_buguiyi']
#选择特征
od_appear_feature = ['o_appear_count','d_appear_count','o_appear_count_rank','d_appear_count_rank',
                     'o_appear_count_rank_buguiyi','d_appear_count_rank_buguiyi','od_couple_count']

##########################################  协同特征  #############################################
xietong_data = pd.read_csv('./xietong_divide_shenzhen.csv', index_col=False)

xietong_feature = xietong_data.columns.to_list()

binary_feat = [feat for feat in plans.columns.tolist() if feat not in ['sid','plans',]]
print('特征加载完成')
#保存选择的特征
Select_features = or_feature + origin_num_feature + od_appear_feature + plan_feature + od_feature +\
                  distance_feature + all_time_feature +  all_profiles_svd_feature + plan_feature +\
                  od_appear_feature + xietong_feature
#使用的特征

feature = [col for col in Select_features if col not in ['req_time','click_mode','sid', 'pid','dewPoint','humidity','humidity','windBearing','windSpeed']]
# Out:
# 特征加载
# 特征加载完成

# %%
data_binary = plans.merge(data[Select_features], on='sid', how='left')
# data_binary['dist_diff'] = data_binary['distance'] - data_binary['od_manhattan_distance_detail']
data_binary['label'] = data_binary[['transport_mode','click_mode']].apply(lambda row:1 if row['transport_mode']==row['click_mode'] else 0,axis=1)
gc.collect()
feature += binary_feat

# %%
def split(data):
    train_index = (data.req_time < '2018-11-23') 
    train_x     = data[train_index][feature].reset_index(drop=True)
    train_y     = data[train_index].label.reset_index(drop=True)

    valid_index = (data.req_time > '2018-11-23') & (data.req_time < '2018-12-01')
    valid_x     = data[valid_index][feature].reset_index(drop=True)
    valid_y     = data[valid_index].label.reset_index(drop=True)

    test_index = (data.req_time > '2018-12-01')
    test_x     = data[test_index][feature].reset_index(drop=True)
    gc.collect()
    return train_x, train_y, valid_x, valid_y

train_x, train_y, valid_x, valid_y = split(data_binary)

# %%
lgb_binary_para = {'boosting_type': 'gbdt',
                 'objective': 'binary',
                 'num_leaves': 31,
                 'learning_rate': 0.05,
                 'feature_fraction': 0.9,
                 'bagging_fraction': 0.9,
                 'bagging_seed': 0,
                 'bagging_freq': 1,
                 'verbose': 1,
                 'seed': 42,
                 'reg_alpha':7.5,
                 'reg_lambda':2}

lgb_model = lgb.LGBMClassifier(**lgb_binary_para, n_estimators=4000, n_jobs=8)
eval_set = [(train_x, train_y),(valid_x, valid_y)]
lgb_model.fit(train_x, train_y, eval_set=eval_set, eval_metric=['auc'], verbose=10, early_stopping_rounds=100)
SCORE = lgb_model.best_score_['valid_1']['auc']
# Out:
# Training until validation scores don't improve for 100 rounds.
# [10]	training's binary_logloss: 0.375388	training's auc: 0.903256	valid_1's binary_logloss: 0.372745	valid_1's auc: 0.911127
# [20]	training's binary_logloss: 0.325655	training's auc: 0.906787	valid_1's binary_logloss: 0.320315	valid_1's auc: 0.914384
# [30]	training's binary_logloss: 0.303032	training's auc: 0.908765	valid_1's binary_logloss: 0.296136	valid_1's auc: 0.916137
# [40]	training's binary_logloss: 0.292174	training's auc: 0.90963	valid_1's binary_logloss: 0.284261	valid_1's auc: 0.916987
# [50]	training's binary_logloss: 0.286569	training's auc: 0.91078	valid_1's binary_logloss: 0.278024	valid_1's auc: 0.918111
# [60]	training's binary_logloss: 0.283469	training's auc: 0.911635	valid_1's binary_logloss: 0.274567	valid_1's auc: 0.918932
# [70]	training's binary_logloss: 0.281445	training's auc: 0.912432	valid_1's binary_logloss: 0.272292	valid_1's auc: 0.919678
# [80]	training's binary_logloss: 0.280126	training's auc: 0.913122	valid_1's binary_logloss: 0.270791	valid_1's auc: 0.920341
# [90]	training's binary_logloss: 0.278867	training's auc: 0.913892	valid_1's binary_logloss: 0.269406	valid_1's auc: 0.921051
# [100]	training's binary_logloss: 0.278026	training's auc: 0.914382	valid_1's binary_logloss: 0.268472	valid_1's auc: 0.92151
# [110]	training's binary_logloss: 0.277257	training's auc: 0.914866	valid_1's binary_logloss: 0.267832	valid_1's auc: 0.92185
# [120]	training's binary_logloss: 0.276544	training's auc: 0.915324	valid_1's binary_logloss: 0.267277	valid_1's auc: 0.922164
# [130]	training's binary_logloss: 0.275937	training's auc: 0.915734	valid_1's binary_logloss: 0.266887	valid_1's auc: 0.922411
# [140]	training's binary_logloss: 0.275461	training's auc: 0.916058	valid_1's binary_logloss: 0.266496	valid_1's auc: 0.922658
# [150]	training's binary_logloss: 0.275013	training's auc: 0.916347	valid_1's binary_logloss: 0.266188	valid_1's auc: 0.922844
# [160]	training's binary_logloss: 0.274638	training's auc: 0.9166	valid_1's binary_logloss: 0.265926	valid_1's auc: 0.923011
# [170]	training's binary_logloss: 0.274294	training's auc: 0.916834	valid_1's binary_logloss: 0.265678	valid_1's auc: 0.923171
# [180]	training's binary_logloss: 0.274029	training's auc: 0.917017	valid_1's binary_logloss: 0.265468	valid_1's auc: 0.923309
# [190]	training's binary_logloss: 0.273732	training's auc: 0.917226	valid_1's binary_logloss: 0.265261	valid_1's auc: 0.923443
# [200]	training's binary_logloss: 0.273476	training's auc: 0.917409	valid_1's binary_logloss: 0.265078	valid_1's auc: 0.923557
# [210]	training's binary_logloss: 0.273254	training's auc: 0.917563	valid_1's binary_logloss: 0.264932	valid_1's auc: 0.92365
# [220]	training's binary_logloss: 0.27303	training's auc: 0.917713	valid_1's binary_logloss: 0.264784	valid_1's auc: 0.923738
# [230]	training's binary_logloss: 0.272859	training's auc: 0.917845	valid_1's binary_logloss: 0.264704	valid_1's auc: 0.923785
# [240]	training's binary_logloss: 0.272669	training's auc: 0.917992	valid_1's binary_logloss: 0.264563	valid_1's auc: 0.92388
# [250]	training's binary_logloss: 0.272443	training's auc: 0.918145	valid_1's binary_logloss: 0.264444	valid_1's auc: 0.923958
# [260]	training's binary_logloss: 0.272246	training's auc: 0.918286	valid_1's binary_logloss: 0.264298	valid_1's auc: 0.924052
# [270]	training's binary_logloss: 0.272078	training's auc: 0.918392	valid_1's binary_logloss: 0.264181	valid_1's auc: 0.924124
# [280]	training's binary_logloss: 0.271912	training's auc: 0.918516	valid_1's binary_logloss: 0.264095	valid_1's auc: 0.924179
# [290]	training's binary_logloss: 0.271762	training's auc: 0.918623	valid_1's binary_logloss: 0.264022	valid_1's auc: 0.924228
# [300]	training's binary_logloss: 0.271614	training's auc: 0.918736	valid_1's binary_logloss: 0.263937	valid_1's auc: 0.924285
# [310]	training's binary_logloss: 0.271484	training's auc: 0.918833	valid_1's binary_logloss: 0.263866	valid_1's auc: 0.924332
# [320]	training's binary_logloss: 0.271342	training's auc: 0.918936	valid_1's binary_logloss: 0.263781	valid_1's auc: 0.924384
# [330]	training's binary_logloss: 0.271233	training's auc: 0.919025	valid_1's binary_logloss: 0.263734	valid_1's auc: 0.924419
# [340]	training's binary_logloss: 0.271119	training's auc: 0.919109	valid_1's binary_logloss: 0.263698	valid_1's auc: 0.924442
# [350]	training's binary_logloss: 0.270985	training's auc: 0.919206	valid_1's binary_logloss: 0.263627	valid_1's auc: 0.924486
# [360]	training's binary_logloss: 0.270853	training's auc: 0.9193	valid_1's binary_logloss: 0.26359	valid_1's auc: 0.924512
# [370]	training's binary_logloss: 0.270735	training's auc: 0.919385	valid_1's binary_logloss: 0.263528	valid_1's auc: 0.924545
# [380]	training's binary_logloss: 0.270616	training's auc: 0.919471	valid_1's binary_logloss: 0.263472	valid_1's auc: 0.924581
# [390]	training's binary_logloss: 0.270491	training's auc: 0.919558	valid_1's binary_logloss: 0.263421	valid_1's auc: 0.924614
# [400]	training's binary_logloss: 0.270388	training's auc: 0.919641	valid_1's binary_logloss: 0.263378	valid_1's auc: 0.924643
# [410]	training's binary_logloss: 0.270281	training's auc: 0.91972	valid_1's binary_logloss: 0.263328	valid_1's auc: 0.924676
# [420]	training's binary_logloss: 0.270176	training's auc: 0.919803	valid_1's binary_logloss: 0.26329	valid_1's auc: 0.924704
# [430]	training's binary_logloss: 0.270062	training's auc: 0.919885	valid_1's binary_logloss: 0.26327	valid_1's auc: 0.92472
# [440]	training's binary_logloss: 0.269951	training's auc: 0.919962	valid_1's binary_logloss: 0.263215	valid_1's auc: 0.924752
# [450]	training's binary_logloss: 0.269861	training's auc: 0.920033	valid_1's binary_logloss: 0.263188	valid_1's auc: 0.924768
# [460]	training's binary_logloss: 0.26977	training's auc: 0.920103	valid_1's binary_logloss: 0.263166	valid_1's auc: 0.924779
# [470]	training's binary_logloss: 0.269665	training's auc: 0.920178	valid_1's binary_logloss: 0.263122	valid_1's auc: 0.924808
# [480]	training's binary_logloss: 0.269557	training's auc: 0.920259	valid_1's binary_logloss: 0.263076	valid_1's auc: 0.924837
# [490]	training's binary_logloss: 0.269458	training's auc: 0.92034	valid_1's binary_logloss: 0.263048	valid_1's auc: 0.92486
# [500]	training's binary_logloss: 0.269363	training's auc: 0.920407	valid_1's binary_logloss: 0.263015	valid_1's auc: 0.924881
# [510]	training's binary_logloss: 0.26926	training's auc: 0.920477	valid_1's binary_logloss: 0.262974	valid_1's auc: 0.924904
# [520]	training's binary_logloss: 0.269165	training's auc: 0.92055	valid_1's binary_logloss: 0.262927	valid_1's auc: 0.924936
# [530]	training's binary_logloss: 0.269074	training's auc: 0.920618	valid_1's binary_logloss: 0.262903	valid_1's auc: 0.924951
# [540]	training's binary_logloss: 0.268986	training's auc: 0.920682	valid_1's binary_logloss: 0.262875	valid_1's auc: 0.924969
# [550]	training's binary_logloss: 0.268908	training's auc: 0.920733	valid_1's binary_logloss: 0.262858	valid_1's auc: 0.924978
# [560]	training's binary_logloss: 0.268817	training's auc: 0.920799	valid_1's binary_logloss: 0.26283	valid_1's auc: 0.924996
# [570]	training's binary_logloss: 0.268736	training's auc: 0.920861	valid_1's binary_logloss: 0.262807	valid_1's auc: 0.925013
# [580]	training's binary_logloss: 0.268657	training's auc: 0.920927	valid_1's binary_logloss: 0.26279	valid_1's auc: 0.925023
# [590]	training's binary_logloss: 0.268573	training's auc: 0.920996	valid_1's binary_logloss: 0.262773	valid_1's auc: 0.92504
# [600]	training's binary_logloss: 0.268492	training's auc: 0.921057	valid_1's binary_logloss: 0.262746	valid_1's auc: 0.92506
# [610]	training's binary_logloss: 0.268391	training's auc: 0.921137	valid_1's binary_logloss: 0.262718	valid_1's auc: 0.925078
# [620]	training's binary_logloss: 0.268306	training's auc: 0.921204	valid_1's binary_logloss: 0.262697	valid_1's auc: 0.92509
# [630]	training's binary_logloss: 0.26822	training's auc: 0.921269	valid_1's binary_logloss: 0.262669	valid_1's auc: 0.925106
# [640]	training's binary_logloss: 0.268125	training's auc: 0.921331	valid_1's binary_logloss: 0.262637	valid_1's auc: 0.925125
# [650]	training's binary_logloss: 0.268048	training's auc: 0.921388	valid_1's binary_logloss: 0.262621	valid_1's auc: 0.925136
# [660]	training's binary_logloss: 0.267969	training's auc: 0.921453	valid_1's binary_logloss: 0.262607	valid_1's auc: 0.925145
# [670]	training's binary_logloss: 0.267879	training's auc: 0.921519	valid_1's binary_logloss: 0.262578	valid_1's auc: 0.925162
# [680]	training's binary_logloss: 0.267803	training's auc: 0.921577	valid_1's binary_logloss: 0.262558	valid_1's auc: 0.925173
# [690]	training's binary_logloss: 0.267723	training's auc: 0.921638	valid_1's binary_logloss: 0.262535	valid_1's auc: 0.925189
# [700]	training's binary_logloss: 0.267649	training's auc: 0.921695	valid_1's binary_logloss: 0.262522	valid_1's auc: 0.925196
# [710]	training's binary_logloss: 0.267579	training's auc: 0.921745	valid_1's binary_logloss: 0.262513	valid_1's auc: 0.925203
# [720]	training's binary_logloss: 0.267504	training's auc: 0.921801	valid_1's binary_logloss: 0.262493	valid_1's auc: 0.925221
# [730]	training's binary_logloss: 0.267424	training's auc: 0.921859	valid_1's binary_logloss: 0.262476	valid_1's auc: 0.925231
# [740]	training's binary_logloss: 0.267348	training's auc: 0.921908	valid_1's binary_logloss: 0.262458	valid_1's auc: 0.925243
# [750]	training's binary_logloss: 0.267269	training's auc: 0.921964	valid_1's binary_logloss: 0.26244	valid_1's auc: 0.925251
# [760]	training's binary_logloss: 0.267193	training's auc: 0.922015	valid_1's binary_logloss: 0.26243	valid_1's auc: 0.925255
# [770]	training's binary_logloss: 0.267118	training's auc: 0.92207	valid_1's binary_logloss: 0.262408	valid_1's auc: 0.925268
# [780]	training's binary_logloss: 0.267042	training's auc: 0.922126	valid_1's binary_logloss: 0.262396	valid_1's auc: 0.925277
# [790]	training's binary_logloss: 0.266968	training's auc: 0.922192	valid_1's binary_logloss: 0.262382	valid_1's auc: 0.925287
# [800]	training's binary_logloss: 0.266884	training's auc: 0.92226	valid_1's binary_logloss: 0.262362	valid_1's auc: 0.925297
# [810]	training's binary_logloss: 0.266799	training's auc: 0.922325	valid_1's binary_logloss: 0.262352	valid_1's auc: 0.925305
# [820]	training's binary_logloss: 0.26673	training's auc: 0.922377	valid_1's binary_logloss: 0.262323	valid_1's auc: 0.925324
# [830]	training's binary_logloss: 0.266657	training's auc: 0.922431	valid_1's binary_logloss: 0.262304	valid_1's auc: 0.925332
# [840]	training's binary_logloss: 0.266584	training's auc: 0.922488	valid_1's binary_logloss: 0.262292	valid_1's auc: 0.925337
# [850]	training's binary_logloss: 0.266518	training's auc: 0.922539	valid_1's binary_logloss: 0.262278	valid_1's auc: 0.925344
# [860]	training's binary_logloss: 0.266448	training's auc: 0.922593	valid_1's binary_logloss: 0.262265	valid_1's auc: 0.925355
# [870]	training's binary_logloss: 0.266378	training's auc: 0.922647	valid_1's binary_logloss: 0.262248	valid_1's auc: 0.925368
# [880]	training's binary_logloss: 0.266301	training's auc: 0.922696	valid_1's binary_logloss: 0.26223	valid_1's auc: 0.925379
# [890]	training's binary_logloss: 0.266235	training's auc: 0.922745	valid_1's binary_logloss: 0.262221	valid_1's auc: 0.925384
# [900]	training's binary_logloss: 0.266169	training's auc: 0.922797	valid_1's binary_logloss: 0.262211	valid_1's auc: 0.925392
# [910]	training's binary_logloss: 0.266092	training's auc: 0.922867	valid_1's binary_logloss: 0.262194	valid_1's auc: 0.925403
# [920]	training's binary_logloss: 0.266019	training's auc: 0.922922	valid_1's binary_logloss: 0.26218	valid_1's auc: 0.925414
# [930]	training's binary_logloss: 0.265953	training's auc: 0.922975	valid_1's binary_logloss: 0.262165	valid_1's auc: 0.925425
# [940]	training's binary_logloss: 0.265888	training's auc: 0.92303	valid_1's binary_logloss: 0.262158	valid_1's auc: 0.925429
# [950]	training's binary_logloss: 0.265817	training's auc: 0.923083	valid_1's binary_logloss: 0.262148	valid_1's auc: 0.925436
# [960]	training's binary_logloss: 0.265741	training's auc: 0.923142	valid_1's binary_logloss: 0.26213	valid_1's auc: 0.925452
# [970]	training's binary_logloss: 0.265667	training's auc: 0.923197	valid_1's binary_logloss: 0.262118	valid_1's auc: 0.925461
# [980]	training's binary_logloss: 0.265595	training's auc: 0.92326	valid_1's binary_logloss: 0.262111	valid_1's auc: 0.925466
# [990]	training's binary_logloss: 0.265526	training's auc: 0.923313	valid_1's binary_logloss: 0.262099	valid_1's auc: 0.925474
# [1000]	training's binary_logloss: 0.265455	training's auc: 0.923373	valid_1's binary_logloss: 0.262088	valid_1's auc: 0.925484
# [1010]	training's binary_logloss: 0.265391	training's auc: 0.923422	valid_1's binary_logloss: 0.262078	valid_1's auc: 0.925492
# [1020]	training's binary_logloss: 0.265326	training's auc: 0.923474	valid_1's binary_logloss: 0.262067	valid_1's auc: 0.925499
# [1030]	training's binary_logloss: 0.265262	training's auc: 0.923522	valid_1's binary_logloss: 0.262062	valid_1's auc: 0.925502
# [1040]	training's binary_logloss: 0.265195	training's auc: 0.923575	valid_1's binary_logloss: 0.262047	valid_1's auc: 0.925514
# [1050]	training's binary_logloss: 0.265127	training's auc: 0.923631	valid_1's binary_logloss: 0.262038	valid_1's auc: 0.925522
# [1060]	training's binary_logloss: 0.265061	training's auc: 0.923683	valid_1's binary_logloss: 0.262033	valid_1's auc: 0.925524
# [1070]	training's binary_logloss: 0.264994	training's auc: 0.923731	valid_1's binary_logloss: 0.262018	valid_1's auc: 0.925535
# [1080]	training's binary_logloss: 0.26493	training's auc: 0.923777	valid_1's binary_logloss: 0.26201	valid_1's auc: 0.925542
# [1090]	training's binary_logloss: 0.264866	training's auc: 0.923825	valid_1's binary_logloss: 0.261997	valid_1's auc: 0.925553
# [1100]	training's binary_logloss: 0.264798	training's auc: 0.92387	valid_1's binary_logloss: 0.261985	valid_1's auc: 0.925562
# [1110]	training's binary_logloss: 0.264728	training's auc: 0.923927	valid_1's binary_logloss: 0.26197	valid_1's auc: 0.925573
# [1120]	training's binary_logloss: 0.264666	training's auc: 0.923971	valid_1's binary_logloss: 0.261964	valid_1's auc: 0.925576
# [1130]	training's binary_logloss: 0.264596	training's auc: 0.924021	valid_1's binary_logloss: 0.26195	valid_1's auc: 0.925582
# [1140]	training's binary_logloss: 0.264534	training's auc: 0.924072	valid_1's binary_logloss: 0.261941	valid_1's auc: 0.925589
# [1150]	training's binary_logloss: 0.264476	training's auc: 0.924112	valid_1's binary_logloss: 0.261934	valid_1's auc: 0.925592
# [1160]	training's binary_logloss: 0.264415	training's auc: 0.924156	valid_1's binary_logloss: 0.261935	valid_1's auc: 0.925594
# [1170]	training's binary_logloss: 0.264347	training's auc: 0.924207	valid_1's binary_logloss: 0.261928	valid_1's auc: 0.925598
# [1180]	training's binary_logloss: 0.264276	training's auc: 0.924259	valid_1's binary_logloss: 0.261921	valid_1's auc: 0.925604
# [1190]	training's binary_logloss: 0.264205	training's auc: 0.924314	valid_1's binary_logloss: 0.26191	valid_1's auc: 0.925609
# [1200]	training's binary_logloss: 0.264145	training's auc: 0.924362	valid_1's binary_logloss: 0.261904	valid_1's auc: 0.925617
# [1210]	training's binary_logloss: 0.264086	training's auc: 0.924407	valid_1's binary_logloss: 0.261893	valid_1's auc: 0.925624
# [1220]	training's binary_logloss: 0.264018	training's auc: 0.924457	valid_1's binary_logloss: 0.261889	valid_1's auc: 0.925627
# [1230]	training's binary_logloss: 0.263955	training's auc: 0.924512	valid_1's binary_logloss: 0.261882	valid_1's auc: 0.925632
# [1240]	training's binary_logloss: 0.263889	training's auc: 0.924558	valid_1's binary_logloss: 0.261873	valid_1's auc: 0.925635
# [1250]	training's binary_logloss: 0.263828	training's auc: 0.924603	valid_1's binary_logloss: 0.261863	valid_1's auc: 0.92564
# [1260]	training's binary_logloss: 0.263773	training's auc: 0.924651	valid_1's binary_logloss: 0.261855	valid_1's auc: 0.925645
# [1270]	training's binary_logloss: 0.263714	training's auc: 0.924699	valid_1's binary_logloss: 0.261854	valid_1's auc: 0.925649
# [1280]	training's binary_logloss: 0.263652	training's auc: 0.924747	valid_1's binary_logloss: 0.261847	valid_1's auc: 0.925655
# [1290]	training's binary_logloss: 0.263596	training's auc: 0.92479	valid_1's binary_logloss: 0.261837	valid_1's auc: 0.925661
# [1300]	training's binary_logloss: 0.263537	training's auc: 0.924836	valid_1's binary_logloss: 0.261831	valid_1's auc: 0.925663
# [1310]	training's binary_logloss: 0.263472	training's auc: 0.924886	valid_1's binary_logloss: 0.26182	valid_1's auc: 0.925674
# [1320]	training's binary_logloss: 0.263409	training's auc: 0.924935	valid_1's binary_logloss: 0.261811	valid_1's auc: 0.925681
# [1330]	training's binary_logloss: 0.263347	training's auc: 0.924978	valid_1's binary_logloss: 0.261796	valid_1's auc: 0.925684
# [1340]	training's binary_logloss: 0.263281	training's auc: 0.925029	valid_1's binary_logloss: 0.261793	valid_1's auc: 0.925685
# [1350]	training's binary_logloss: 0.263207	training's auc: 0.925082	valid_1's binary_logloss: 0.26179	valid_1's auc: 0.92569
# [1360]	training's binary_logloss: 0.263154	training's auc: 0.925121	valid_1's binary_logloss: 0.261784	valid_1's auc: 0.925693
# [1370]	training's binary_logloss: 0.263091	training's auc: 0.925172	valid_1's binary_logloss: 0.261774	valid_1's auc: 0.9257
# [1380]	training's binary_logloss: 0.263026	training's auc: 0.92522	valid_1's binary_logloss: 0.261772	valid_1's auc: 0.925699
# [1390]	training's binary_logloss: 0.262962	training's auc: 0.925267	valid_1's binary_logloss: 0.261762	valid_1's auc: 0.925706
# [1400]	training's binary_logloss: 0.262903	training's auc: 0.925308	valid_1's binary_logloss: 0.26175	valid_1's auc: 0.925712
# [1410]	training's binary_logloss: 0.262849	training's auc: 0.925349	valid_1's binary_logloss: 0.261747	valid_1's auc: 0.925712
# [1420]	training's binary_logloss: 0.262789	training's auc: 0.925394	valid_1's binary_logloss: 0.261742	valid_1's auc: 0.925713
# [1430]	training's binary_logloss: 0.262727	training's auc: 0.925432	valid_1's binary_logloss: 0.26173	valid_1's auc: 0.925721
# [1440]	training's binary_logloss: 0.262667	training's auc: 0.925475	valid_1's binary_logloss: 0.261727	valid_1's auc: 0.925723
# [1450]	training's binary_logloss: 0.262603	training's auc: 0.925525	valid_1's binary_logloss: 0.261724	valid_1's auc: 0.925729
# [1460]	training's binary_logloss: 0.262535	training's auc: 0.925577	valid_1's binary_logloss: 0.261717	valid_1's auc: 0.925735
# [1470]	training's binary_logloss: 0.262477	training's auc: 0.925618	valid_1's binary_logloss: 0.26171	valid_1's auc: 0.925739
# [1480]	training's binary_logloss: 0.262413	training's auc: 0.92566	valid_1's binary_logloss: 0.261704	valid_1's auc: 0.925743
# [1490]	training's binary_logloss: 0.262359	training's auc: 0.925701	valid_1's binary_logloss: 0.261706	valid_1's auc: 0.925741
# [1500]	training's binary_logloss: 0.2623	training's auc: 0.925738	valid_1's binary_logloss: 0.261706	valid_1's auc: 0.925739
# [1510]	training's binary_logloss: 0.262236	training's auc: 0.925791	valid_1's binary_logloss: 0.261698	valid_1's auc: 0.925746
# [1520]	training's binary_logloss: 0.262178	training's auc: 0.925836	valid_1's binary_logloss: 0.261692	valid_1's auc: 0.92575
# [1530]	training's binary_logloss: 0.262117	training's auc: 0.925882	valid_1's binary_logloss: 0.261694	valid_1's auc: 0.925749
# [1540]	training's binary_logloss: 0.262065	training's auc: 0.925922	valid_1's binary_logloss: 0.26169	valid_1's auc: 0.925751
# [1550]	training's binary_logloss: 0.262001	training's auc: 0.925972	valid_1's binary_logloss: 0.261685	valid_1's auc: 0.925751
# [1560]	training's binary_logloss: 0.261947	training's auc: 0.926014	valid_1's binary_logloss: 0.261675	valid_1's auc: 0.925758
# [1570]	training's binary_logloss: 0.261881	training's auc: 0.926057	valid_1's binary_logloss: 0.261672	valid_1's auc: 0.925761
# [1580]	training's binary_logloss: 0.261831	training's auc: 0.926089	valid_1's binary_logloss: 0.261669	valid_1's auc: 0.925763
# [1590]	training's binary_logloss: 0.26177	training's auc: 0.926137	valid_1's binary_logloss: 0.26166	valid_1's auc: 0.925769
# [1600]	training's binary_logloss: 0.261712	training's auc: 0.926184	valid_1's binary_logloss: 0.261657	valid_1's auc: 0.925769
# [1610]	training's binary_logloss: 0.26165	training's auc: 0.926225	valid_1's binary_logloss: 0.261651	valid_1's auc: 0.92577
# [1620]	training's binary_logloss: 0.261595	training's auc: 0.926265	valid_1's binary_logloss: 0.261648	valid_1's auc: 0.925773
# [1630]	training's binary_logloss: 0.26154	training's auc: 0.926311	valid_1's binary_logloss: 0.261651	valid_1's auc: 0.925769
# [1640]	training's binary_logloss: 0.261474	training's auc: 0.926361	valid_1's binary_logloss: 0.261648	valid_1's auc: 0.925772
# [1650]	training's binary_logloss: 0.261419	training's auc: 0.926412	valid_1's binary_logloss: 0.261642	valid_1's auc: 0.925776
# [1660]	training's binary_logloss: 0.261367	training's auc: 0.926452	valid_1's binary_logloss: 0.26164	valid_1's auc: 0.925779
# [1670]	training's binary_logloss: 0.261314	training's auc: 0.926488	valid_1's binary_logloss: 0.261639	valid_1's auc: 0.925778
# [1680]	training's binary_logloss: 0.261264	training's auc: 0.926521	valid_1's binary_logloss: 0.261636	valid_1's auc: 0.92578
# [1690]	training's binary_logloss: 0.261211	training's auc: 0.926561	valid_1's binary_logloss: 0.261633	valid_1's auc: 0.925782
# [1700]	training's binary_logloss: 0.261158	training's auc: 0.926599	valid_1's binary_logloss: 0.261634	valid_1's auc: 0.925784
# [1710]	training's binary_logloss: 0.261101	training's auc: 0.926644	valid_1's binary_logloss: 0.261628	valid_1's auc: 0.925784
# [1720]	training's binary_logloss: 0.261045	training's auc: 0.926687	valid_1's binary_logloss: 0.261629	valid_1's auc: 0.925782
# [1730]	training's binary_logloss: 0.260983	training's auc: 0.926734	valid_1's binary_logloss: 0.261625	valid_1's auc: 0.925783
# [1740]	training's binary_logloss: 0.260928	training's auc: 0.926774	valid_1's binary_logloss: 0.261619	valid_1's auc: 0.925786
# [1750]	training's binary_logloss: 0.260876	training's auc: 0.926811	valid_1's binary_logloss: 0.261614	valid_1's auc: 0.92579
# [1760]	training's binary_logloss: 0.260819	training's auc: 0.926859	valid_1's binary_logloss: 0.261611	valid_1's auc: 0.925792
# [1770]	training's binary_logloss: 0.26076	training's auc: 0.926906	valid_1's binary_logloss: 0.261614	valid_1's auc: 0.92579
# [1780]	training's binary_logloss: 0.2607	training's auc: 0.926947	valid_1's binary_logloss: 0.261605	valid_1's auc: 0.925794
# [1790]	training's binary_logloss: 0.260644	training's auc: 0.92699	valid_1's binary_logloss: 0.261605	valid_1's auc: 0.925793
# [1800]	training's binary_logloss: 0.260586	training's auc: 0.927033	valid_1's binary_logloss: 0.261601	valid_1's auc: 0.925795
# [1810]	training's binary_logloss: 0.260528	training's auc: 0.927074	valid_1's binary_logloss: 0.2616	valid_1's auc: 0.925794
# [1820]	training's binary_logloss: 0.260471	training's auc: 0.927123	valid_1's binary_logloss: 0.261592	valid_1's auc: 0.925801
# [1830]	training's binary_logloss: 0.260411	training's auc: 0.927163	valid_1's binary_logloss: 0.26158	valid_1's auc: 0.925806
# [1840]	training's binary_logloss: 0.260351	training's auc: 0.927212	valid_1's binary_logloss: 0.261577	valid_1's auc: 0.925805
# [1850]	training's binary_logloss: 0.260292	training's auc: 0.927257	valid_1's binary_logloss: 0.261574	valid_1's auc: 0.925806
# [1860]	training's binary_logloss: 0.260239	training's auc: 0.927299	valid_1's binary_logloss: 0.261574	valid_1's auc: 0.925803
# [1870]	training's binary_logloss: 0.260188	training's auc: 0.927338	valid_1's binary_logloss: 0.261574	valid_1's auc: 0.925804
# [1880]	training's binary_logloss: 0.260132	training's auc: 0.927377	valid_1's binary_logloss: 0.261577	valid_1's auc: 0.925803
# [1890]	training's binary_logloss: 0.260081	training's auc: 0.927412	valid_1's binary_logloss: 0.261574	valid_1's auc: 0.925805
# [1900]	training's binary_logloss: 0.260021	training's auc: 0.927455	valid_1's binary_logloss: 0.26157	valid_1's auc: 0.925808
# [1910]	training's binary_logloss: 0.259968	training's auc: 0.927497	valid_1's binary_logloss: 0.261566	valid_1's auc: 0.925808
# [1920]	training's binary_logloss: 0.259912	training's auc: 0.927541	valid_1's binary_logloss: 0.261569	valid_1's auc: 0.925806
# [1930]	training's binary_logloss: 0.259856	training's auc: 0.927582	valid_1's binary_logloss: 0.261569	valid_1's auc: 0.925804
# [1940]	training's binary_logloss: 0.259805	training's auc: 0.927619	valid_1's binary_logloss: 0.261563	valid_1's auc: 0.925808
# [1950]	training's binary_logloss: 0.25975	training's auc: 0.927664	valid_1's binary_logloss: 0.261558	valid_1's auc: 0.925814
# [1960]	training's binary_logloss: 0.259685	training's auc: 0.927703	valid_1's binary_logloss: 0.261549	valid_1's auc: 0.925819
# [1970]	training's binary_logloss: 0.259629	training's auc: 0.927745	valid_1's binary_logloss: 0.26154	valid_1's auc: 0.925827
# [1980]	training's binary_logloss: 0.259566	training's auc: 0.927788	valid_1's binary_logloss: 0.261536	valid_1's auc: 0.925831
# [1990]	training's binary_logloss: 0.259511	training's auc: 0.927831	valid_1's binary_logloss: 0.261533	valid_1's auc: 0.925831
# [2000]	training's binary_logloss: 0.259449	training's auc: 0.927881	valid_1's binary_logloss: 0.26153	valid_1's auc: 0.925831
# Did not meet early stopping. Best iteration is:
# [2000]	training's binary_logloss: 0.259449	training's auc: 0.927881	valid_1's binary_logloss: 0.26153	valid_1's auc: 0.925831

# %%
def get_result(result, data_X):
    result['proba'] = lgb_model.predict_proba(data_X)[:,1]
    result = (result.sort_values(GR_COLS + ["proba"], ascending=[True, True, True, False]))
    result = result.groupby(GR_COLS)['impresssions'].first().rename('recommend_mode')
    return result

valid_binary_df = pd.DataFrame()
valid_index = (data_binary.req_time > '2018-11-23') & (data_binary.req_time < '2018-12-01')
valid_binary_df['sid'] = data_binary[valid_index]['sid'].values
valid_binary_df['click_mode'] = data_binary[valid_index]['click_mode'].values
valid_binary_df['transport_mode'] = data_binary[valid_index]['transport_mode'].values
valid_binary_df['proba'] = lgb_model.predict_proba(valid_X)[:,1]

valid_binary_df = (valid_binary_df.sort_values(["sid","proba"], ascending=[True,False]))
valid_binary_df = valid_binary_df.groupby(['sid'])[['click_mode','transport_mode']].first()
f1_score(y_true=valid_binary_df['click_mode'], y_pred=valid_binary_df['transport_mode'], average='weighted')

valid_binary_df['proba'] = lgb_model.predict_proba(valid_x)[:,1]

valid_binary_df = (valid_binary_df.sort_values(["sid","proba"], ascending=[True,False]))
valid_binary_df = valid_binary_df.groupby(['sid'])[['click_mode','transport_mode']].first()
f1_score(y_true=valid_binary_df['click_mode'], y_pred=valid_binary_df['transport_mode'], average='weighted')
# Out:
# 0.6774892959919135

# %%
valid_proba_df['click_mode'] = valid_y
dic_ = valid_proba_df['click_mode'].value_counts(normalize = True)
valid_proba_df['recommend_mode'] = proba_process(valid_proba)
get_weighted_fscore(y_true = valid_proba_df['click_mode'] , y_pred = valid_proba_df['recommend_mode'])
