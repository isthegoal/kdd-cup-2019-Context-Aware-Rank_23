# %%
import pandas as pd
import urllib.request
import json
import re
import time
from urllib.parse import quote

# %%
address_all_info=pd.read_csv('./address_all_info.csv',index_col=0)
len(address_all_info['address'])

address_all_info['address_lng'] = address_all_info['address'].apply(lambda x: float(x.split(',')[0]))
address_all_info['address_lat'] = address_all_info['address'].apply(lambda x: float(x.split(',')[1]))

# %%
len(set(address_all_info['address']))
# Out:
# 16964

# %%
import re
from tqdm import tqdm
Subway_number_list=[]
Bus_number_list=[]
Hospital_number_list=[]
University_number_list=[]
Middle_School_number_list=[]
Residential_number_list=[]
Office_number_list=[]
Gourmet_number_list=[]
Entertainment_number_list=[]
Financial_number_list=[]
Tourism_number_list=[]
Railway_Station_number_list=[]
Airport_number_list=[]
Office_building_number_list=[]
mall_list=[]
for r_i, row  in  tqdm(address_all_info.iterrows()):
    lng=row['address_lng']
    lat=row['address_lat']    
    
    ####################    写字楼    #####################
    resp_orig = urllib.request.urlopen('http://api.map.baidu.com/place/v2/search?query='+quote('写字楼')+'&location='+str(lat)+','+str(lng)+'&radius=1000&output=xml&ak=LlNVsWOsqmKwlqkUEBmzbpmbu2GAc2Dl')
    #print('http://api.map.baidu.com/place/v2/search?query='+quote('公交')+'&location='+str(lat)+','+str(lng)+'&radius=10&output=xml&ak=LlNVsWOsqmKwlqkUEBmzbpmbu2GAc2Dl')
    resp_str=str(resp_orig.read().decode('utf8'))


    regex = re.compile("uid")
    # 调用 findall 函数
    Office_building_number_list.append(len(regex.findall(resp_str))/2)
    ####################    医院    #####################
    resp_orig = urllib.request.urlopen('http://api.map.baidu.com/place/v2/search?query='+quote('医院')+'&location='+str(lat)+','+str(lng)+'&radius=1000&output=xml&ak=LlNVsWOsqmKwlqkUEBmzbpmbu2GAc2Dl')
    #print('http://api.map.baidu.com/place/v2/search?query='+quote('公交')+'&location='+str(lat)+','+str(lng)+'&radius=10&output=xml&ak=LlNVsWOsqmKwlqkUEBmzbpmbu2GAc2Dl')
    resp_str=str(resp_orig.read().decode('utf8'))

    time.sleep(1) 
    regex = re.compile("uid")
    # 调用 findall 函数
    Hospital_number_list.append(len(regex.findall(resp_str))/2)    
    ####################    商场    #####################
    resp_orig = urllib.request.urlopen('http://api.map.baidu.com/place/v2/search?query='+quote('商场')+'&location='+str(lat)+','+str(lng)+'&radius=1000&output=xml&ak=LlNVsWOsqmKwlqkUEBmzbpmbu2GAc2Dl')
    #print('http://api.map.baidu.com/place/v2/search?query='+quote('公交')+'&location='+str(lat)+','+str(lng)+'&radius=10&output=xml&ak=LlNVsWOsqmKwlqkUEBmzbpmbu2GAc2Dl')
    resp_str=str(resp_orig.read().decode('utf8'))


    regex = re.compile("uid")
    # 调用 findall 函数
    mall_list.append(len(regex.findall(resp_str))/2)
    time.sleep(1)
# Out:
# 0it [00:00, ?it/s]
#
#
#
#
#
#
#
# 1it [00:02,  2.74s/it]
#
#
#
#
#
#
#
# 2it [00:05,  2.73s/it]
#
#
#
#
#
#
#
# 3it [00:08,  2.74s/it]
#
#
#
#
#
#
#
# 4it [00:10,  2.63s/it]
#
#
#
#
#
#
#
# 5it [00:13,  2.58s/it]
#
#
#
#
#
#
#
# 6it [00:15,  2.50s/it]
#
#
#
#
#
#
#
# 7it [00:17,  2.45s/it]
#
#
#
#
#
#
#
# 8it [00:20,  2.46s/it]
#
#
#
#
#
#
#
# 9it [00:22,  2.41s/it]
#
#
#
#
#
#
#
# 10it [00:24,  2.41s/it]
#
#
#
#
#
#
#
# 11it [00:27,  2.38s/it]
#
#
#
#
#
#
#
# 12it [00:29,  2.36s/it]
#
#
#
#
#
#
#
# 13it [00:31,  2.34s/it]
#
#
#
#
#
#
#
# 14it [00:34,  2.37s/it]
#
#
#
#
#
#
#
# 15it [00:36,  2.37s/it]
#
#
#
#
#
#
#
# 16it [00:38,  2.35s/it]
#
#
#
#
#
#
#
# 17it [00:41,  2.34s/it]
#
#
#
#
#
#
#
# 18it [00:43,  2.33s/it]
#
#
#
#
#
#
#
# 19it [00:45,  2.32s/it]
#
#
#
#
#
#
#
# 20it [00:48,  2.32s/it]
#
#
#
#
#
#
#
# 21it [00:50,  2.31s/it]
#
#
#
#
#
#
#
# 22it [00:52,  2.32s/it]
#
#
#
#
#
#
#
# 23it [00:55,  2.32s/it]
#
#
#
#
#
#
#
# 24it [00:57,  2.31s/it]
#
#
#
#
#
#
#
# 25it [00:59,  2.30s/it]
#
#
#
#
#
#
#
# 26it [01:02,  2.33s/it]
#
#
#
#
#
#
#
# 27it [01:04,  2.32s/it]
#
#
#
#
#
#
#
# 28it [01:06,  2.32s/it]
#
#
#
#
#
#
#
# 29it [01:09,  2.33s/it]
#
#
#
#
#
#
#
# 30it [01:11,  2.32s/it]
#
#
#
#
#
#
#
# 31it [01:13,  2.33s/it]
#
#
#
#
#
#
#
# 32it [01:16,  2.32s/it]
#
#
#
#
#
#
#
# 33it [01:18,  2.32s/it]
#
#
#
#
#
#
#
# 34it [01:20,  2.32s/it]
#
#
#
#
#
#
#
# 35it [01:23,  2.34s/it]
#
#
#
#
#
#
#
# 36it [01:25,  2.34s/it]
#
#
#
#
#
#
#
# 37it [01:27,  2.34s/it]
#
#
#
#
#
#
#
# 38it [01:30,  2.33s/it]
#
#
#
#
#
#
#
# 39it [01:32,  2.35s/it]
#
#
#
#
#
#
#
# 40it [01:34,  2.36s/it]
#
#
#
#
#
#
#
# 41it [01:37,  2.34s/it]
#
#
#
#
#
#
#
# 42it [01:39,  2.33s/it]
#
#
#
#
#
#
#
# 43it [01:41,  2.33s/it]
#
#
#
#
#
#
#
# 44it [01:44,  2.33s/it]
#
#
#
#
#
#
#
# 45it [01:46,  2.33s/it]
#
#
#
#
#
#
#
# 46it [01:48,  2.32s/it]
#
#
#
#
#
#
#
# 47it [01:51,  2.33s/it]
#
#
#
#
#
#
#
# 48it [01:53,  2.33s/it]
#
#
#
#
#
#
#
# 49it [01:55,  2.33s/it]
#
#
#
#
#
#
#
# 50it [01:58,  2.35s/it]
#
#
#
#
#
#
#
# 51it [02:00,  2.35s/it]
#
#
#
#
#
#
#
# 52it [02:02,  2.35s/it]
#
#
#
#
#
#
#
# 53it [02:05,  2.38s/it]
#
#
#
#
#
#
#
# 54it [02:07,  2.36s/it]
#
#
#
#
#
#
#
# 55it [02:09,  2.35s/it]
#
#
#
#
#
#
#
# 56it [02:12,  2.34s/it]
#
#
#
#
#
#
#
# 57it [02:14,  2.34s/it]
#
#
#
#
#
#
#
# 58it [02:16,  2.33s/it]
#
#
#
#
#
#
#
# 59it [02:19,  2.32s/it]
#
#
#
#
#
#
#
# 60it [02:21,  2.34s/it]
#
#
#
#
#
#
#
# 61it [02:23,  2.33s/it]
#
#
#
#
#
#
#
# 62it [02:26,  2.33s/it]
#
#
#
#
#
#
#
# 63it [02:28,  2.35s/it]
#
#
#
#
#
#
#
# 64it [02:30,  2.34s/it]
#
#
#
#
#
#
#
# 65it [02:33,  2.33s/it]
#
#
#
#
#
#
#
# 66it [02:35,  2.36s/it]
#
#
#
#
#
#
#
# 67it [02:37,  2.36s/it]
#
#
#
#
#
#
#
# 68it [02:40,  2.34s/it]
#
#
#
#
#
#
#
# 69it [02:42,  2.43s/it]
#
#
#
#
#
#
#
# 70it [02:45,  2.49s/it]
#
#
#
#
#
#
#
# 71it [02:47,  2.45s/it]
#
#
#
#
#
#
#
# 72it [02:50,  2.41s/it]
#
#
#
#
#
#
#
# 73it [02:52,  2.39s/it]
#
#
#
#
#
#
#
# 74it [02:54,  2.37s/it]
#
#
#
#
#
#
#
# 75it [02:57,  2.37s/it]
#
#
#
#
#
#
#
# 76it [02:59,  2.34s/it]
#
#
#
#
#
#
#
# 77it [03:01,  2.33s/it]
#
#
#
#
#
#
#
# 78it [03:04,  2.34s/it]
#
#
#
#
#
#
#
# 79it [03:06,  2.36s/it]
#
#
#
#
#
#
#
# 80it [03:08,  2.34s/it]
#
#
#
#
#
#
#
# 81it [03:11,  2.32s/it]
#
#
#
#
#
#
#
# 82it [03:13,  2.32s/it]
#
#
#
#
#
#
#
# 83it [03:15,  2.31s/it]
#
#
#
#
#
#
#
# 84it [03:18,  2.30s/it]
#
#
#
#
#
#
#
# 85it [03:20,  2.30s/it]
#
#
#
#
#
#
#
# 86it [03:22,  2.31s/it]
#
#
#
#
#
#
#
# 87it [03:25,  2.33s/it]
#
#
#
#
#
#
#
# 88it [03:27,  2.32s/it]
#
#
#
#
#
#
#
# 89it [03:29,  2.31s/it]
#
#
#
#
#
#
#
# 90it [03:31,  2.31s/it]
#
#
#
#
#
#
#
# 91it [03:34,  2.31s/it]
#
#
#
#
#
#
#
# 92it [03:36,  2.30s/it]
#
#
#
#
#
#
#
# 93it [03:38,  2.31s/it]
#
#
#
#
#
#
#
# 94it [03:41,  2.30s/it]
#
#
#
#
#
#
#
# 95it [03:43,  2.30s/it]
#
#
#
#
#
#
#
# 96it [03:45,  2.30s/it]
#
#
#
#
#
#
#
# 97it [03:48,  2.31s/it]
#
#
#
#
#
#
#
# 98it [03:50,  2.33s/it]
#
#
#
#
#
#
#
# 99it [03:52,  2.37s/it]
#
#
#
#
#
#
#
# 100it [03:55,  2.39s/it]
#
#
#
#
#
#
#
# 101it [03:57,  2.42s/it]
#
#
#
#
#
#
#
# 102it [04:00,  2.38s/it]
#
#
#
#
#
#
#
# 103it [04:02,  2.36s/it]
#
#
#
#
#
#
#
# 104it [04:04,  2.34s/it]
#
#
#
#
#
#
#
# 105it [04:07,  2.33s/it]
#
#
#
#
#
#
#
# 106it [04:09,  2.33s/it]
#
#
#
#
#
#
#
# 107it [04:11,  2.34s/it]
#
#
#
#
#
#
#
# 108it [04:14,  2.34s/it]
#
#
#
#
#
#
#
# 109it [04:16,  2.33s/it]
#
#
#
#
#
#
#
# 110it [04:18,  2.32s/it]
#
#
#
#
#
#
#
# 111it [04:21,  2.33s/it]
#
#
#
#
#
#
#
# 112it [04:23,  2.35s/it]
#
#
#
#
#
#
#
# 113it [04:25,  2.33s/it]
#
#
#
#
#
#
#
# 114it [04:28,  2.33s/it]
#
#
#
#
#
#
#
# 115it [04:30,  2.33s/it]
#
#
#
#
#
#
#
# 116it [04:32,  2.32s/it]
#
#
#
#
#
#
#
# 117it [04:35,  2.33s/it]
#
#
#
#
#
#
#
# 118it [04:37,  2.35s/it]
#
#
#
#
#
#
#
# 119it [04:39,  2.35s/it]
#
#
#
#
#
#
#
# 120it [04:42,  2.34s/it]
#
#
#
#
#
#
#
# 121it [04:44,  2.33s/it]
#
#
#
#
#
#
#
# 122it [04:46,  2.32s/it]
#
#
#
#
#
#
#
# 123it [04:48,  2.31s/it]
#
#
#
#
#
#
#
# 124it [04:51,  2.31s/it]
#
#
#
#
#
#
#
# 125it [04:53,  2.30s/it]
#
#
#
#
#
#
#
# 126it [04:55,  2.30s/it]
#
#
#
#
#
#
#
# 127it [04:58,  2.31s/it]
#
#
#
#
#
#
#
# 128it [05:00,  2.33s/it]
#
#
#
#
#
#
#
# 129it [05:02,  2.34s/it]
#
#
#
#
#
#
#
# 130it [05:05,  2.32s/it]
#
#
#
#
#
#
#
# 131it [05:07,  2.32s/it]
#
#
#
#
#
#
#
# 132it [05:09,  2.31s/it]
#
#
#
#
#
#
#
# 133it [05:12,  2.30s/it]
#
#
#
#
#
#
#
# 134it [05:14,  2.32s/it]
#
#
#
#
#
#
#
# 135it [05:16,  2.32s/it]
#
#
#
#
#
#
#
# 136it [05:19,  2.31s/it]
#
#
#
#
#
#
#
# 137it [05:21,  2.33s/it]
#
#
#
#
#
#
#
# 138it [05:23,  2.35s/it]
#
#
#
#
#
#
#
# 139it [05:26,  2.34s/it]
#
#
#
#
#
#
#
# 140it [05:28,  2.34s/it]
#
#
#
#
#
#
#
# 141it [05:30,  2.34s/it]
#
#
#
#
#
#
#
# 142it [05:33,  2.33s/it]
#
#
#
#
#
#
#
# 143it [05:35,  2.34s/it]
#
#
#
#
#
#
#
# 144it [05:37,  2.34s/it]
#
#
#
#
#
#
#
# 145it [05:40,  2.34s/it]
#
#
#
#
#
#
#
# 146it [05:42,  2.34s/it]
#
#
#
#
#
#
#
# 147it [05:44,  2.35s/it]
#
#
#
#
#
#
#
# 148it [05:47,  2.32s/it]
#
#
#
#
#
#
#
# 149it [05:49,  2.36s/it]
#
#
#
#
#
#
#
# 150it [05:52,  2.38s/it]
#
#
#
#
#
#
#
# 151it [05:54,  2.36s/it]
#
#
#
#
#
#
#
# 152it [05:56,  2.37s/it]
#
#
#
#
#
#
#
# 153it [05:59,  2.37s/it]
#
#
#
#
#
#
#
# 154it [06:01,  2.35s/it]
#
#
#
#
#
#
#
# 155it [06:03,  2.35s/it]
#
#
#
#
#
#
#
# 156it [06:06,  2.35s/it]
#
#
#
#
#
#
#
# 157it [06:08,  2.33s/it]
#
#
#
#
#
#
#
# 158it [06:10,  2.33s/it]
#
#
#
#
#
#
#
# 159it [06:13,  2.34s/it]
#
#
#
#
#
#
#
# 160it [06:15,  2.34s/it]
#
#
#
#
#
#
#
# 161it [06:17,  2.34s/it]
#
#
#
#
#
#
#
# 162it [06:20,  2.34s/it]
#
#
#
#
#
#
#
# 163it [06:22,  2.35s/it]
#
#
#
#
#
#
#
# 164it [06:24,  2.35s/it]
#
#
#
#
#
#
#
# 165it [06:27,  2.34s/it]
#
#
#
#
#
#
#
# 166it [06:29,  2.33s/it]
#
#
#
#
#
#
#
# 167it [06:31,  2.35s/it]
#
#
#
#
#
#
#
# 168it [06:34,  2.33s/it]
#
#
#
#
#
#
#
# 169it [06:36,  2.32s/it]
#
#
#
#
#
#
#
# 170it [06:38,  2.33s/it]
#
#
#
#
#
#
#
# 171it [06:41,  2.32s/it]
#
#
#
#
#
#
#
# 172it [06:43,  2.32s/it]
#
#
#
#
#
#
#
# 173it [06:45,  2.32s/it]
#
#
#
#
#
#
#
# 174it [06:47,  2.31s/it]
#
#
#
#
#
#
#
# 175it [06:50,  2.34s/it]
#
#
#
#
#
#
#
# 176it [06:52,  2.32s/it]
#
#
#
#
#
#
#
# 177it [06:54,  2.31s/it]
#
#
#
#
#
#
#
# 178it [06:57,  2.31s/it]
#
#
#
#
#
#
#
# 179it [06:59,  2.32s/it]
#
#
#
#
#
#
#
# 180it [07:01,  2.32s/it]
#
#
#
#
#
#
#
# 181it [07:04,  2.32s/it]
#
#
#
#
#
#
#
# 182it [07:06,  2.34s/it]
#
#
#
#
#
#
#
# 183it [07:09,  2.38s/it]
#
#
#
#
#
#
#
# 184it [07:11,  2.35s/it]
#
#
#
#
#
#
#
# 185it [07:13,  2.35s/it]
#
#
#
#
#
#
#
# 186it [07:16,  2.35s/it]
#
#
#
#
#
#
#
# 187it [07:18,  2.33s/it]
#
#
#
#
#
#
#
# 188it [07:20,  2.32s/it]
#
#
#
#
#
#
#
# 189it [07:23,  2.33s/it]
#
#
#
#
#
#
#
# 190it [07:25,  2.32s/it]
#
#
#
#
#
#
#
# 191it [07:27,  2.33s/it]
#
#
#
#
#
#
#
# 192it [07:29,  2.33s/it]
#
#
#
#
#
#
#
# 193it [07:32,  2.31s/it]
#
#
#
#
#
#
#
# 194it [07:34,  2.31s/it]
#
#
#
#
#
#
#
# 195it [07:36,  2.35s/it]
#
#
#
#
#
#
#
# 196it [07:39,  2.35s/it]
#
#
#
#
#
#
#
# 197it [07:41,  2.34s/it]
#
#
#
#
#
#
#
# 198it [07:44,  2.36s/it]
#
#
#
#
#
#
#
# 199it [07:46,  2.34s/it]
#
#
#
#
#
#
#
# 200it [07:48,  2.33s/it]
#
#
#
#
#
#
#
# 201it [07:51,  2.33s/it]
#
#
#
#
#
#
#
# 202it [07:53,  2.33s/it]
#
#
#
#
#
#
#
# 203it [07:55,  2.32s/it]
#
#
#
#
#
#
#
# 204it [07:57,  2.33s/it]
#
#
#
#
#
#
#
# 205it [08:00,  2.32s/it]
#
#
#
#
#
#
#
# 206it [08:02,  2.32s/it]
#
#
#
#
#
#
#
# 207it [08:04,  2.32s/it]
#
#
#
#
#
#
#
# 208it [08:08,  2.70s/it]
#
#
#
#
#
#
#
# 209it [08:10,  2.58s/it]
#
#
#
#
#
#
#
# 210it [08:13,  2.49s/it]
#
#
#
#
#
#
#
# 211it [08:15,  2.43s/it]
#
#
#
#
#
#
#
# 212it [08:17,  2.39s/it]
#
#
#
#
#
#
#
# 213it [08:19,  2.36s/it]
#
#
#
#
#
#
#
# 214it [08:22,  2.34s/it]
#
#
#
#
#
#
#
# 215it [08:24,  2.37s/it]
#
#
#
#
#
#
#
# 216it [08:27,  2.35s/it]
#
#
#
#
#
#
#
# 217it [08:29,  2.35s/it]
#
#
#
#
#
#
#
# 218it [08:31,  2.34s/it]
#
#
#
#
#
#
#
# 219it [08:34,  2.39s/it]
#
#
#
#
#
#
#
# 220it [08:36,  2.36s/it]
#
#
#
#
#
#
#
# 221it [08:38,  2.35s/it]
#
#
#
#
#
#
#
# 222it [08:41,  2.35s/it]
#
#
#
#
#
#
#
# 223it [08:43,  2.35s/it]
#
#
#
#
#
#
#
# 224it [08:45,  2.35s/it]
#
#
#
#
#
#
#
# 225it [08:48,  2.34s/it]
#
#
#
#
#
#
#
# 226it [08:50,  2.33s/it]
#
#
#
#
#
#
#
# 227it [08:52,  2.33s/it]
#
#
#
#
#
#
#
# 228it [08:55,  2.34s/it]
#
#
#
#
#
#
#
# 229it [08:57,  2.33s/it]
#
#
#
#
#
#
#
# 230it [08:59,  2.33s/it]
#
#
#
#
#
#
#
# 231it [09:02,  2.34s/it]
#
#
#
#
#
#
#
# 232it [09:04,  2.33s/it]
#
#
#
#
#
#
#
# 233it [09:06,  2.32s/it]
#
#
#
#
#
#
#
# 234it [09:09,  2.31s/it]
#
#
#
#
#
#
#
# 235it [09:11,  2.31s/it]
#
#
#
#
#
#
#
# 236it [09:13,  2.32s/it]
#
#
#
#
#
#
#
# 237it [09:16,  2.33s/it]
#
#
#
#
#
#
#
# 238it [09:18,  2.34s/it]
#
#
#
#
#
#
#
# 239it [09:20,  2.40s/it]
#
#
#
#
#
#
#
# 240it [09:23,  2.39s/it]
#
#
#
#
#
#
#
# 241it [09:25,  2.36s/it]
#
#
#
#
#
#
#
# 242it [09:28,  2.39s/it]
#
#
#
#
#
#
#
# 243it [09:30,  2.38s/it]
#
#
#
#
#
#
#
# 244it [09:32,  2.37s/it]
#
#
#
#
#
#
#
# 245it [09:35,  2.35s/it]
#
#
#
#
#
#
#
# 246it [09:37,  2.34s/it]
#
#
#
#
#
#
#
# 247it [09:39,  2.34s/it]
#
#
#
#
#
#
#
# 248it [09:42,  2.33s/it]
#
#
#
#
#
#
#
# 249it [09:44,  2.32s/it]
#
#
#
#
#
#
#
# 250it [09:46,  2.31s/it]
#
#
#
#
#
#
#
# 251it [09:48,  2.33s/it]
#
#
#
#
#
#
#
# 252it [09:51,  2.34s/it]
#
#
#
#
#
#
#
# 253it [09:53,  2.35s/it]
#
#
#
#
#
#
#
# 254it [09:55,  2.33s/it]
#
#
#
#
#
#
#
# 255it [09:58,  2.33s/it]
#
#
#
#
#
#
#
# 256it [10:00,  2.33s/it]
#
#
#
#
#
#
#
# 257it [10:02,  2.33s/it]
#
#
#
#
#
#
#
# 258it [10:05,  2.33s/it]
# 259it [10:07,  2.32s/it]
#
#
#
#
#
#
#
# 260it [10:09,  2.31s/it]
#
#
#
#
#
#
#
# 261it [10:12,  2.36s/it]
#
#
#
#
#
#
#
# 262it [10:14,  2.35s/it]
#
#
#
#
#
#
#
# 263it [10:17,  2.34s/it]
#
#
#
#
#
#
#
# 264it [10:19,  2.32s/it]
#
#
#
#
#
#
#
# 265it [10:21,  2.32s/it]
#
#
#
#
#
#
#
# 266it [10:23,  2.30s/it]
#
#
#
#
#
#
#
# 267it [10:26,  2.31s/it]
#
#
#
#
#
#
#
# 268it [10:28,  2.30s/it]
#
#
#
#
#
#
#
# 269it [10:30,  2.30s/it]
#
#
#
#
#
#
#
# 270it [10:33,  2.30s/it]
#
#
#
#
#
#
#
# 271it [10:35,  2.30s/it]
#
#
#
#
#
#
#
# 272it [10:37,  2.31s/it]
#
#
#
#
#
#
#
# 273it [10:39,  2.31s/it]
#
#
#
#
#
#
#
# 274it [10:42,  2.30s/it]
#
#
#
#
#
#
#
# 275it [10:44,  2.34s/it]
#
#
#
#
#
#
#
# 276it [10:46,  2.32s/it]
#
#
#
#
#
#
#
# 277it [10:49,  2.31s/it]
#
#
#
#
#
#
#
# 278it [10:51,  2.31s/it]
#
#
#
#
#
#
#
# 279it [10:53,  2.31s/it]
#
#
#
#
#
#
#
# 280it [10:56,  2.32s/it]
#
#
#
#
#
#
#
# 281it [10:58,  2.35s/it]
#
#
#
#
#
#
#
# 282it [11:00,  2.32s/it]
#
#
#
#
#
#
#
# 283it [11:03,  2.31s/it]
#
#
#
#
#
#
#
# 284it [11:05,  2.30s/it]
#
#
#
#
#
#
#
# 285it [11:07,  2.32s/it]
#
#
#
#
#
#
#
# 286it [11:10,  2.30s/it]
#
#
#
#
#
#
#
# 287it [11:12,  2.31s/it]
#
#
#
#
#
#
#
# 288it [11:14,  2.31s/it]
#
#
#
#
#
#
#
# 289it [11:17,  2.30s/it]
#
#
#
#
#
#
#
# 290it [11:19,  2.30s/it]
#
#
#
#
#
#
#
# 291it [11:21,  2.31s/it]
#
#
#
#
#
#
#
# 292it [11:24,  2.34s/it]
#
#
#
#
#
#
#
# 293it [11:26,  2.34s/it]
#
#
#
#
#
#
#
# 294it [11:28,  2.35s/it]
#
#
#
#
#
#
#
# 295it [11:31,  2.33s/it]
#
#
#
#
#
#
#
# 296it [11:33,  2.34s/it]
#
#
#
#
#
#
#
# 297it [11:35,  2.32s/it]
#
#
#
#
#
#
#
# 298it [11:37,  2.31s/it]
#
#
#
#
#
#
#
# 299it [11:40,  2.32s/it]
#
#
#
#
#
#
#
# 300it [11:42,  2.32s/it]
#
#
#
#
#
#
#
# 301it [11:44,  2.31s/it]
#
#
#
#
#
#
#
# 302it [11:47,  2.34s/it]
#
#
#
#
#
#
#
# 303it [11:49,  2.35s/it]
#
#
#
#
#
#
#
# 304it [11:52,  2.36s/it]
#
#
#
#
#
#
#
# 305it [11:54,  2.38s/it]
#
#
#
#
#
#
#
# 306it [11:56,  2.37s/it]
#
#
#
#
#
#
#
# 307it [11:59,  2.34s/it]
#
#
#
#
#
#
#
# 308it [12:01,  2.35s/it]
#
#
#
#
#
#
#
# 309it [12:03,  2.35s/it]
#
#
#
#
#
#
#
# 310it [12:06,  2.33s/it]
#
#
#
#
#
#
#
# 311it [12:08,  2.32s/it]
#
#
#
#
#
#
#
# 312it [12:10,  2.31s/it]
#
#
#
#
#
#
#
# 313it [12:13,  2.33s/it]
#
#
#
#
#
#
#
# 314it [12:15,  2.33s/it]
#
#
#
#
#
#
#
# 315it [12:17,  2.33s/it]
#
#
#
#
#
#
#
# 316it [12:20,  2.33s/it]
#
#
#
#
#
#
#
# 317it [12:22,  2.32s/it]
#
#
#
#
#
#
#
# 318it [12:24,  2.34s/it]
#
#
#
#
#
#
#
# 319it [12:27,  2.35s/it]
#
#
#
#
#
#
#
# 320it [12:29,  2.34s/it]
#
#
#
#
#
#
#
# 321it [12:31,  2.32s/it]
#
#
#
#
#
#
#
# 322it [12:34,  2.31s/it]
#
#
#
#
#
#
#
# 323it [12:36,  2.34s/it]
#
#
#
#
#
#
#
# 324it [12:38,  2.34s/it]
#
#
#
#
#
#
#
# 325it [12:41,  2.33s/it]
#
#
#
#
#
#
#
# 326it [12:43,  2.32s/it]
#
#
#
#
#
#
#
# 327it [12:45,  2.34s/it]
#
#
#
#
#
#
#
# 328it [12:48,  2.32s/it]
#
#
#
#
#
#
#
# 329it [12:50,  2.33s/it]
#
#
#
#
#
#
#
# 330it [12:52,  2.31s/it]
#
#
#
#
#
#
#
# 331it [12:55,  2.33s/it]
#
#
#
#
#
#
#
# 332it [12:57,  2.33s/it]
#
#
#
#
#
#
#
# 333it [12:59,  2.33s/it]
#
#
#
#
#
#
#
# 334it [13:01,  2.31s/it]
#
#
#
#
#
#
#
# 335it [13:04,  2.33s/it]
#
#
#
#
#
#
#
# 336it [13:06,  2.32s/it]
#
#
#
#
#
#
#
# 337it [13:08,  2.33s/it]
#
#
#
#
#
#
#
# 338it [13:11,  2.39s/it]
#
#
#
#
#
#
#
# 339it [13:13,  2.36s/it]
#
#
#
#
#
#
#
# 340it [13:16,  2.33s/it]
#
#
#
#
#
#
#
# 341it [13:18,  2.35s/it]
#
#
#
#
#
#
#
# 342it [13:20,  2.33s/it]
#
#
#
#
#
#
#
# 343it [13:23,  2.33s/it]
#
#
#
#
#
#
#
# 344it [13:25,  2.34s/it]
#
#
#
#
#
#
#
# 345it [13:27,  2.33s/it]
#
#
#
#
#
#
#
# 346it [13:30,  2.32s/it]
#
#
#
#
#
#
#
# 347it [13:32,  2.32s/it]
#
#
#
#
#
#
#
# 348it [13:34,  2.32s/it]
#
#
#
#
#
#
#
# 349it [13:37,  2.33s/it]
#
#
#
#
#
#
#
# 350it [13:39,  2.32s/it]
#
#
#
#
#
#
#
# 351it [13:41,  2.31s/it]
#
#
#
#
#
#
#
# 352it [13:43,  2.33s/it]
#
#
#
#
#
#
#
# 353it [13:46,  2.34s/it]
#
#
#
#
#
#
#
# 354it [13:48,  2.33s/it]
#
#
#
#
#
#
#
# 355it [13:51,  2.34s/it]
#
#
#
#
#
#
#
# 356it [13:53,  2.32s/it]
#
#
#
#
#
#
#
# 357it [13:55,  2.33s/it]
#
#
#
#
#
#
#
# 358it [13:58,  2.34s/it]
#
#
#
#
#
#
#
# 359it [14:00,  2.33s/it]
#
#
#
#
#
#
#
# 360it [14:02,  2.31s/it]
#
#
#
#
#
#
#
# 361it [14:04,  2.33s/it]
#
#
#
#
#
#
#
# 362it [14:07,  2.32s/it]
#
#
#
#
#
#
#
# 363it [14:09,  2.33s/it]
#
#
#
#
#
#
#
# 364it [14:11,  2.33s/it]
#
#
#
#
#
#
#
# 365it [14:14,  2.35s/it]
#
#
#
#
#
#
#
# 366it [14:16,  2.33s/it]
#
#
#
#
#
#
#
# 367it [14:18,  2.31s/it]
#
#
#
#
#
#
#
# 368it [14:21,  2.30s/it]
#
#
#
#
#
#
#
# 369it [14:23,  2.37s/it]
#
#
#
#
#
#
#
# 370it [14:26,  2.36s/it]
#
#
#
#
#
#
#
# 371it [14:28,  2.35s/it]
#
#
#
#
#
#
#
# 372it [14:30,  2.39s/it]
#
#
#
#
#
#
#
# 373it [14:33,  2.38s/it]
#
#
#
#
#
#
#
# 374it [14:35,  2.37s/it]
#
#
#
#
#
#
#
# 375it [14:37,  2.37s/it]
#
#
#
#
#
#
#
# 376it [14:40,  2.35s/it]
#
#
#
#
#
#
#
# 377it [14:42,  2.35s/it]
#
#
#
#
#
#
#
# 378it [14:44,  2.33s/it]
#
#
#
#
#
#
#
# 379it [14:47,  2.32s/it]
#
#
#
#
#
#
#
# 380it [14:49,  2.32s/it]
#
#
#
#
#
#
#
# 381it [14:51,  2.31s/it]
#
#
#
#
#
#
#
# 382it [14:54,  2.33s/it]
#
#
#
#
#
#
#
# 383it [14:56,  2.32s/it]
#
#
#
#
#
#
#
# 384it [14:58,  2.31s/it]
#
#
#
#
#
#
#
# 385it [15:01,  2.31s/it]
#
#
#
#
#
#
#
# 386it [15:03,  2.30s/it]
#
#
#
#
#
#
#
# 387it [15:05,  2.32s/it]
#
#
#
#
#
#
#
# 388it [15:07,  2.32s/it]
#
#
#
#
#
#
#
# 389it [15:10,  2.36s/it]
#
#
#
#
#
#
#
# 390it [15:12,  2.35s/it]
#
#
#
#
#
#
#
# 391it [15:15,  2.36s/it]
#
#
#
#
#
#
#
# 392it [15:17,  2.35s/it]
#
#
#
#
#
#
#
# 393it [15:19,  2.34s/it]
#
#
#
#
#
#
#
# 394it [15:22,  2.34s/it]
#
#
#
#
#
#
#
# 395it [15:24,  2.32s/it]
#
#
#
#
#
#
#
# 396it [15:26,  2.32s/it]
#
#
#
#
#
#
#
# 397it [15:29,  2.33s/it]
#
#
#
#
#
#
#
# 398it [15:31,  2.34s/it]
#
#
#
#
#
#
#
# 399it [15:33,  2.35s/it]
#
#
#
#
#
#
#
# 400it [15:36,  2.37s/it]
#
#
#
#
#
#
#
# 401it [15:38,  2.36s/it]
#
#
#
#
#
#
#
# 402it [15:40,  2.35s/it]
#
#
#
#
#
#
#
# 403it [15:43,  2.33s/it]
#
#
#
#
#
#
#
# 404it [15:45,  2.33s/it]
#
#
#
#
#
#
#
# 405it [15:47,  2.31s/it]
#
#
#
#
#
#
#
# 406it [15:50,  2.31s/it]
#
#
#
#
#
#
#
# 407it [15:52,  2.33s/it]
#
#
#
#
#
#
#
# 408it [15:54,  2.34s/it]
#
#
#
#
#
#
#
# 409it [15:57,  2.34s/it]
#
#
#
#
#
#
#
# 410it [15:59,  2.34s/it]
#
#
#
#
#
#
#
# 411it [16:01,  2.36s/it]
#
#
#
#
#
#
#
# 412it [16:04,  2.36s/it]
#
#
#
#
#
#
#
# 413it [16:06,  2.36s/it]
#
#
#
#
#
#
#
# 414it [16:08,  2.34s/it]
#
#
#
#
#
#
#
# 415it [16:11,  2.34s/it]
#
#
#
#
#
#
#
# 416it [16:13,  2.34s/it]
#
#
#
#
#
#
#
# 417it [16:16,  2.38s/it]
#
#
#
#
#
#
#
# 418it [16:18,  2.38s/it]
#
#
#
#
#
#
#
# 419it [16:20,  2.39s/it]
#
#
#
#
#
#
#
# 420it [16:23,  2.38s/it]
#
#
#
#
#
#
#
# 421it [16:25,  2.36s/it]
#
#
#
#
#
#
#
# 422it [16:27,  2.36s/it]
#
#
#
#
#
#
#
# 423it [16:30,  2.38s/it]
#
#
#
#
#
#
#
# 424it [16:32,  2.35s/it]
#
#
#
#
#
#
#
# 425it [16:35,  2.39s/it]
#
#
#
#
#
#
#
# 426it [16:37,  2.39s/it]
#
#
#
#
#
#
#
# 427it [16:39,  2.36s/it]
#
#
#
#
#
#
#
# 428it [16:42,  2.35s/it]
#
#
#
#
#
#
#
# 429it [16:44,  2.34s/it]
#
#
#
#
#
#
#
# 430it [16:46,  2.34s/it]
#
#
#
#
#
#
#
# 431it [16:48,  2.32s/it]
#
#
#
#
#
#
#
# 432it [16:51,  2.31s/it]
#
#
#
#
#
#
#
# 433it [16:53,  2.31s/it]
#
#
#
#
#
#
#
# 434it [16:55,  2.30s/it]
#
#
#
#
#
#
#
# 435it [16:58,  2.29s/it]
#
#
#
#
#
#
#
# 436it [17:00,  2.31s/it]
#
#
#
#
#
#
#
# 437it [17:02,  2.33s/it]
#
#
#
#
#
#
#
# 438it [17:05,  2.32s/it]
#
#
#
#
#
#
#
# 439it [17:07,  2.31s/it]
#
#
#
#
#
#
#
# 440it [17:09,  2.32s/it]
#
#
#
#
#
#
#
# 441it [17:12,  2.32s/it]
#
#
#
#
#
#
#
# 442it [17:14,  2.31s/it]
#
#
#
#
#
#
#
# 443it [17:16,  2.30s/it]
#
#
#
#
#
#
#
# 444it [17:19,  2.33s/it]
#
#
#
#
#
#
#
# 445it [17:21,  2.33s/it]
#
#
#
#
#
#
#
# 446it [17:23,  2.32s/it]
#
#
#
#
#
#
#
# 447it [17:26,  2.32s/it]
#
#
#
#
#
#
#
# 448it [17:28,  2.34s/it]
#
#
#
#
#
#
#
# 449it [17:30,  2.33s/it]
#
#
#
#
#
#
#
# 450it [17:33,  2.36s/it]
#
#
#
#
#
#
#
# 451it [17:35,  2.34s/it]
#
#
#
#
#
#
#
# 452it [17:37,  2.32s/it]
#
#
#
#
#
#
#
# 453it [17:39,  2.31s/it]
#
#
#
#
#
#
#
# 454it [17:42,  2.31s/it]
#
#
#
#
#
#
#
# 455it [17:44,  2.37s/it]
#
#
#
#
#
#
#
# 456it [17:47,  2.39s/it]
#
#
#
#
#
#
#
# 457it [17:49,  2.37s/it]
#
#
#
#
#
#
#
# 458it [17:51,  2.34s/it]
#
#
#
#
#
#
#
# 459it [17:54,  2.33s/it]
#
#
#
#
#
#
#
# 460it [17:56,  2.35s/it]
#
#
#
#
#
#
#
# 461it [17:58,  2.35s/it]
#
#
#
#
#
#
#
# 462it [18:01,  2.33s/it]
#
#
#
#
#
#
#
# 463it [18:03,  2.31s/it]
#
#
#
#
#
#
#
# 464it [18:05,  2.32s/it]
#
#
#
#
#
#
#
# 465it [18:08,  2.33s/it]
#
#
#
#
#
#
#
# 466it [18:10,  2.32s/it]
#
#
#
#
#
#
#
# 467it [18:12,  2.32s/it]
#
#
#
#
#
#
#
# 468it [18:15,  2.33s/it]
#
#
#
#
#
#
#
# 469it [18:17,  2.34s/it]
#
#
#
#
#
#
#
# 470it [18:19,  2.34s/it]
#
#
#
#
#
#
#
# 471it [18:22,  2.34s/it]
#
#
#
#
#
#
#
# 472it [18:24,  2.33s/it]
#
#
#
#
#
#
#
# 473it [18:26,  2.31s/it]
#
#
#
#
#
#
#
# 474it [18:29,  2.34s/it]
#
#
#
#
#
#
#
# 475it [18:31,  2.33s/it]
#
#
#
#
#
#
#
# 476it [18:33,  2.33s/it]
#
#
#
#
#
#
#
# 477it [18:36,  2.32s/it]
#
#
#
#
#
#
#
# 478it [18:38,  2.32s/it]
#
#
#
#
#
#
#
# 479it [18:40,  2.35s/it]
#
#
#
#
#
#
#
# 480it [18:43,  2.34s/it]
#
#
#
#
#
#
#
# 481it [18:45,  2.32s/it]
#
#
#
#
#
#
#
# 482it [18:47,  2.33s/it]
#
#
#
#
#
#
#
# 483it [18:50,  2.32s/it]
#
#
#
#
#
#
#
# 484it [18:52,  2.32s/it]
#
#
#
#
#
#
#
# 485it [18:54,  2.35s/it]
#
#
#
#
#
#
#
# 486it [18:57,  2.33s/it]
#
#
#
#
#
#
#
# 487it [18:59,  2.34s/it]
#
#
#
#
#
#
#
# 488it [19:01,  2.33s/it]
#
#
#
#
#
#
#
# 489it [19:04,  2.33s/it]
#
#
#
#
#
#
#
# 490it [19:06,  2.33s/it]
#
#
#
#
#
#
#
# 491it [19:08,  2.33s/it]
#
#
#
#
#
#
#
# 492it [19:11,  2.33s/it]
#
#
#
#
#
#
#
# 493it [19:13,  2.31s/it]
#
#
#
#
#
#
#
# 494it [19:15,  2.31s/it]
#
#
#
#
#
#
#
# 495it [19:17,  2.30s/it]
#
#
#
#
#
#
#
# 496it [19:20,  2.30s/it]
#
#
#
#
#
#
#
# 497it [19:22,  2.32s/it]
#
#
#
#
#
#
#
# 498it [19:24,  2.34s/it]
#
#
#
#
#
#
#
# 499it [19:27,  2.33s/it]
#
#
#
#
#
#
#
# 500it [19:29,  2.33s/it]
#
#
#
#
#
#
#
# 501it [19:31,  2.31s/it]
#
#
#
#
#
#
#
# 502it [19:34,  2.31s/it]
#
#
#
#
#
#
#
# 503it [19:36,  2.32s/it]
#
#
#
#
#
#
#
# 504it [19:38,  2.33s/it]
#
#
#
#
#
#
#
# 505it [19:41,  2.33s/it]
#
#
#
#
#
#
#
# 506it [19:43,  2.31s/it]
#
#
#
#
#
#
#
# 507it [19:45,  2.30s/it]
#
#
#
#
#
#
#
# 508it [19:48,  2.29s/it]
#
#
#
#
#
#
#
# 509it [19:50,  2.32s/it]
#
#
#
#
#
#
#
# 510it [19:52,  2.33s/it]
#
#
#
#
#
#
#
# 511it [19:55,  2.32s/it]
#
#
#
#
#
#
#
# 512it [19:57,  2.31s/it]
#
#
#
#
#
#
#
# 513it [19:59,  2.31s/it]
#
#
#
#
#
#
#
# 514it [20:01,  2.31s/it]
# 515it [20:04,  2.31s/it]
#
#
#
#
#
#
#
# 516it [20:06,  2.30s/it]
#
#
#
#
#
#
#
# 517it [20:08,  2.29s/it]
#
#
#
#
#
#
#
# 518it [20:11,  2.29s/it]
#
#
#
#
#
#
#
# 519it [20:13,  2.29s/it]
#
#
#
#
#
#
#
# 520it [20:15,  2.31s/it]
#
#
#
#
#
#
#
# 521it [20:18,  2.31s/it]
#
#
#
#
#
#
#
# 522it [20:20,  2.32s/it]
#
#
#
#
#
#
#
# 523it [20:22,  2.33s/it]
#
#
#
#
#
#
#
# 524it [20:25,  2.32s/it]
#
#
#
#
#
#
#
# 525it [20:27,  2.33s/it]
#
#
#
#
#
#
#
# 526it [20:29,  2.32s/it]
#
#
#
#
#
#
#
# 527it [20:32,  2.33s/it]
#
#
#
#
#
#
#
# 528it [20:34,  2.34s/it]
#
#
#
#
#
#
#
# 529it [20:36,  2.33s/it]
#
#
#
#
#
#
#
# 530it [20:39,  2.32s/it]
#
#
#
#
#
#
#
# 531it [20:41,  2.34s/it]
#
#
#
#
#
#
#
# 532it [20:43,  2.40s/it]
#
#
#
#
#
#
#
# 533it [20:46,  2.37s/it]
#
#
#
#
#
#
#
# 534it [20:48,  2.34s/it]
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-19-232b56af0b6f> in <module>
#      39     Hospital_number_list.append(len(regex.findall(resp_str))/2)
#      40     ####################    商场    #####################
# ---> 41     resp_orig = urllib.request.urlopen('http://api.map.baidu.com/place/v2/search?query='+quote('商场')+'&location='+str(lat)+','+str(lng)+'&radius=1000&output=xml&ak=LlNVsWOsqmKwlqkUEBmzbpmbu2GAc2Dl')
#      42     #print('http://api.map.baidu.com/place/v2/search?query='+quote('公交')+'&location='+str(lat)+','+str(lng)+'&radius=10&output=xml&ak=LlNVsWOsqmKwlqkUEBmzbpmbu2GAc2Dl')
#      43     resp_str=str(resp_orig.read().decode('utf8'))
#
# D:\Anaconda3\envs\python35\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#     225 def install_opener(opener):
#
# D:\Anaconda3\envs\python35\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     530         for processor in self.process_response.get(protocol, []):
#     531             meth = getattr(processor, meth_name)
# --> 532             response = meth(req, response)
#     533
#     534         return response
#
# D:\Anaconda3\envs\python35\lib\urllib\request.py in http_response(self, request, response)
#     640         if not (200 <= code < 300):
#     641             response = self.parent.error(
# --> 642                 'http', request, response, code, msg, hdrs)
#     643
#     644         return response
#
# D:\Anaconda3\envs\python35\lib\urllib\request.py in error(self, proto, *args)
#     568         if http_err:
#     569             args = (dict, 'default', 'http_error_default') + orig_args
# --> 570             return self._call_chain(*args)
#     571
#     572 # XXX probably also want an abstract factory that knows when it makes
#
# D:\Anaconda3\envs\python35\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# D:\Anaconda3\envs\python35\lib\urllib\request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     648 class HTTPDefaultErrorHandler(BaseHandler):
#     649     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 650         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     651
#     652 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 503: Forwarding failure

# %%
address_all_info['Office_building_number_list']=Office_building_number_list
address_all_info['mill_number_list']=mall_list
address_all_info['Hospital_number_list']=Hospital_number_list
address_all_info.to_csv('./address_all_info_final_hospital.csv')
